# %% [markdown]
# ## Получаем данные

# %%
import pandas as pd

# %%
import numpy as np
from tqdm import tqdm_notebook

# %%
df_ratings = pd.read_csv('../data/ml-latest-small/ratings.csv')
df_movies = pd.read_csv('../data/ml-latest-small/movies.csv')

# %%
df = pd.merge(df_ratings, df_movies, on='movieId')

# %%
del df['timestamp']
del df['genres']

# %%
df.head()
# Out:
#    userId  movieId  rating             title
# 0       1        1     4.0  Toy Story (1995)
# 1       5        1     4.0  Toy Story (1995)
# 2       7        1     4.5  Toy Story (1995)
# 3      15        1     2.5  Toy Story (1995)
# 4      17        1     4.5  Toy Story (1995)

# %% [markdown]
# ## Формируем векторное описание для фильма

# %%
df['userId'].describe()
# Out:
# count    100836.000000
# mean        326.127564
# std         182.618491
# min           1.000000
# 25%         177.000000
# 50%         325.000000
# 75%         477.000000
# max         610.000000
# Name: userId, dtype: float64

# %%
MAX_USER_ID = 610
MIN_USER_ID = 1

# %%
movie_names = df['title'].unique()

# %%
movie_names = movie_names.tolist()

# %%
movie_to_vector = {}

# %%
for movie in tqdm_notebook(movie_names):
    movie_to_vector[movie] = np.zeros((MAX_USER_ID,))
    for r in df[df['title'] == movie].iterrows():
        movie_to_vector[movie][r[1]['userId'] - MIN_USER_ID] = r[1]['rating']
# Out:
# HBox(children=(IntProgress(value=0, max=9719), HTML(value='')))

# %% [markdown]
# ## Ищем похожие

# %%
def find_similar(movie, dist_func, top=10):
    distances = {}
    target_movie = movie_to_vector[movie]
    for m in movie_names:
        distances[m] = dist_func(target_movie, movie_to_vector[m])
        
    distances_with_idx = [(i, distances[m]) for i, m in enumerate(movie_names)]
    distances_with_idx = sorted(distances_with_idx, key=lambda t: t[1], reverse=False)
    distances_with_idx = distances_with_idx[:top]
    
    return [(movie_names[i], d) for i, d in distances_with_idx]

# %%
from scipy.spatial.distance import cosine, euclidean, cityblock

# %%
find_similar('Toy Story (1995)', cityblock)
# Out:
# [('Toy Story (1995)', 0.0),
#  ('Toy Story 2 (1999)', 608.5),
#  ("Bug's Life, A (1998)", 698.5),
#  ('Groundhog Day (1993)', 714.0),
#  ('Nutty Professor, The (1996)', 714.0),
#  ('Willy Wonka & the Chocolate Factory (1971)', 718.0),
#  ('Mission: Impossible (1996)', 722.0),
#  ('Babe (1995)', 722.5),
#  ('Monsters, Inc. (2001)', 725.0),
#  ('Toy Story 3 (2010)', 728.0)]

# %% [markdown]
# ## User 2 Item

# %%
# !pip install surprise
# Out:
# Requirement already satisfied: surprise in /home/truename/anaconda3/lib/python3.7/site-packages (0.1)
# Requirement already satisfied: scikit-surprise in /home/truename/anaconda3/lib/python3.7/site-packages (from surprise) (1.0.6)
# Requirement already satisfied: six>=1.10.0 in /home/truename/anaconda3/lib/python3.7/site-packages (from scikit-surprise->surprise) (1.11.0)
# Requirement already satisfied: scipy>=1.0.0 in /home/truename/anaconda3/lib/python3.7/site-packages (from scikit-surprise->surprise) (1.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/truename/anaconda3/lib/python3.7/site-packages (from scikit-surprise->surprise) (0.13.2)
# Requirement already satisfied: numpy>=1.11.2 in /home/truename/anaconda3/lib/python3.7/site-packages (from scikit-surprise->surprise) (1.15.1)
# You are using pip version 19.0.2, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from surprise import Dataset, Reader, KNNBasic
from surprise.model_selection import train_test_split
from surprise import accuracy

# %%
df_ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
df_for_surpise = df_ratings[['userId', 'movieId', 'rating']]

# %%
df_for_surpise.columns = ['uid', 'iid', 'rating']

# %%
df_for_surpise.head()
# Out:
#    uid  iid  rating
# 0    1    1     4.0
# 1    1    3     4.0
# 2    1    6     4.0
# 3    1   47     5.0
# 4    1   50     5.0

# %%
reader = Reader(rating_scale=(0.5, 5))

# %%
dataset = Dataset.load_from_df(df_for_surpise, reader)

# %%
trainset, testset = train_test_split(dataset, test_size=0.2)

# %%
algo = KNNBasic(k=40, sim_options={'name': 'cosine', 'user_based': True}, user_based=True)

# %%
algo.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
predictions = algo.test(testset)

# %%
accuracy.mae(predictions)
# Out:
# MAE:  0.7488
# 0.7487718446404766

# %%
testset
# Out:
# [(64, 25, 3.5),
#  (43, 165, 5.0),
#  (495, 1059, 5.0),
#  (424, 288, 4.0),
#  (292, 80489, 3.5),
#  (298, 112552, 3.5),
#  (312, 2628, 3.0),
#  (381, 2100, 3.5),
#  (600, 480, 3.0),
#  (135, 3624, 4.0),
#  (44, 1391, 2.0),
#  (414, 7137, 3.5),
#  (462, 337, 2.5),
#  (276, 364, 5.0),
#  (336, 2762, 4.5),
#  (249, 1199, 3.5),
#  (241, 318, 3.5),
#  (438, 4011, 3.5),
#  (385, 541, 5.0),
#  (608, 3264, 2.5),
#  (364, 1210, 3.0),
#  (4, 2843, 5.0),
#  (495, 2918, 4.5),
#  (19, 47, 3.0),
#  (89, 146244, 4.0),
#  (555, 2402, 3.0),
#  (288, 3699, 3.0),
#  (263, 8796, 2.0),
#  (453, 2447, 3.0),
#  (429, 468, 3.0),
#  (80, 85414, 4.5),
#  (453, 1405, 5.0),
#  (249, 2949, 4.0),
#  (460, 6539, 4.0),
#  (113, 1043, 2.0),
#  (477, 2, 4.0),
#  (532, 1200, 5.0),
#  (380, 5476, 3.0),
#  (216, 3067, 3.0),
#  (232, 39446, 4.0),
#  (586, 2058, 4.0),
#  (476, 594, 4.0),
#  (63, 2997, 3.0),
#  (448, 148888, 2.0),
#  (18, 68159, 4.0),
#  (105, 2762, 4.5),
#  (599, 60069, 4.0),
#  (18, 63131, 3.5),
#  (572, 1958, 4.0),
#  (600, 26662, 4.5),
#  (233, 1206, 4.0),
#  (307, 2716, 3.0),
#  (606, 6934, 2.0),
#  (469, 3809, 4.0),
#  (294, 663, 1.0),
#  (19, 1379, 2.0),
#  (385, 1196, 5.0),
#  (32, 203, 4.0),
#  (238, 4265, 3.0),
#  (18, 8784, 3.5),
#  (62, 122896, 3.5),
#  (599, 5081, 2.0),
#  (590, 8807, 2.5),
#  (438, 2723, 2.0),
#  (111, 41573, 3.5),
#  (430, 6373, 3.0),
#  (119, 5218, 4.0),
#  (71, 160, 3.0),
#  (6, 361, 4.0),
#  (560, 2605, 4.0),
#  (546, 3408, 4.0),
#  (414, 2986, 2.0),
#  (160, 1371, 2.0),
#  (262, 440, 2.0),
#  (480, 3484, 3.0),
#  (249, 111, 4.5),
#  (367, 898, 4.0),
#  (599, 94478, 2.0),
#  (6, 342, 3.0),
#  (453, 3273, 1.0),
#  (230, 41569, 4.0),
#  (84, 105, 3.0),
#  (105, 2329, 4.0),
#  (603, 4014, 2.0),
#  (377, 585, 4.0),
#  (202, 2956, 3.0),
#  (89, 65588, 2.5),
#  (590, 367, 3.0),
#  (307, 48385, 4.5),
#  (182, 3925, 5.0),
#  (325, 1968, 3.0),
#  (380, 1702, 3.0),
#  (599, 3270, 3.5),
#  (177, 5387, 4.5),
#  (168, 923, 5.0),
#  (543, 4226, 5.0),
#  (414, 58156, 2.0),
#  (483, 19, 3.5),
#  (305, 316, 3.0),
#  (448, 89087, 2.0),
#  (304, 3175, 5.0),
#  (438, 193, 1.0),
#  (483, 208, 3.0),
#  (226, 7263, 4.0),
#  (414, 428, 4.0),
#  (234, 2571, 5.0),
#  (589, 356, 5.0),
#  (275, 4037, 5.0),
#  (474, 266, 2.0),
#  (422, 3943, 3.0),
#  (103, 2797, 4.0),
#  (425, 6300, 4.0),
#  (600, 1274, 3.5),
#  (525, 8874, 4.5),
#  (606, 26810, 4.5),
#  (28, 62394, 2.0),
#  (414, 355, 1.0),
#  (174, 527, 3.0),
#  (500, 2572, 3.0),
#  (304, 474, 5.0),
#  (382, 59501, 4.0),
#  (198, 4388, 1.0),
#  (22, 3751, 4.0),
#  (275, 1188, 3.0),
#  (600, 2013, 3.5),
#  (274, 3534, 2.5),
#  (490, 64839, 4.0),
#  (599, 288, 3.0),
#  (475, 1198, 5.0),
#  (514, 5952, 2.0),
#  (380, 2762, 5.0),
#  (226, 6006, 3.0),
#  (17, 780, 4.0),
#  (381, 4370, 3.0),
#  (339, 1247, 3.0),
#  (81, 329, 4.0),
#  (564, 88785, 4.0),
#  (239, 440, 4.0),
#  (577, 377, 3.0),
#  (495, 208, 3.0),
#  (365, 76077, 4.0),
#  (415, 92535, 4.5),
#  (474, 2122, 1.0),
#  (112, 47, 5.0),
#  (599, 5945, 1.5),
#  (382, 95167, 4.0),
#  (490, 4246, 2.5),
#  (217, 504, 3.0),
#  (357, 1923, 4.0),
#  (275, 3794, 2.0),
#  (610, 7367, 3.5),
#  (18, 2291, 4.0),
#  (140, 1097, 4.0),
#  (74, 1263, 5.0),
#  (18, 8950, 4.0),
#  (492, 1407, 5.0),
#  (1, 923, 5.0),
#  (477, 2009, 4.0),
#  (599, 165, 3.0),
#  (429, 270, 5.0),
#  (21, 47997, 5.0),
#  (294, 355, 3.0),
#  (584, 338, 4.0),
#  (305, 33660, 4.0),
#  (249, 2485, 3.0),
#  (422, 1213, 5.0),
#  (373, 160, 1.0),
#  (597, 2064, 5.0),
#  (462, 1222, 3.0),
#  (596, 904, 4.5),
#  (608, 1645, 4.5),
#  (18, 7018, 3.5),
#  (391, 1214, 4.0),
#  (18, 112552, 4.5),
#  (483, 1278, 4.0),
#  (177, 2053, 2.0),
#  (514, 187595, 3.0),
#  (608, 1464, 2.0),
#  (599, 8985, 1.5),
#  (21, 1909, 2.0),
#  (546, 1035, 2.0),
#  (144, 380, 3.0),
#  (607, 1717, 5.0),
#  (438, 2549, 3.0),
#  (19, 3699, 2.0),
#  (365, 148172, 3.5),
#  (599, 542, 2.0),
#  (307, 33681, 1.0),
#  (74, 7234, 5.0),
#  (480, 45730, 3.5),
#  (596, 1356, 4.5),
#  (222, 81932, 4.5),
#  (68, 4816, 4.0),
#  (427, 5081, 4.0),
#  (387, 2599, 4.0),
#  (395, 60, 3.0),
#  (34, 3717, 4.5),
#  (600, 2616, 2.5),
#  (286, 500, 3.5),
#  (152, 1207, 4.5),
#  (474, 56607, 3.5),
#  (298, 158238, 2.0),
#  (453, 5299, 4.0),
#  (528, 48516, 4.5),
#  (608, 8967, 3.0),
#  (239, 370, 2.5),
#  (318, 71535, 4.0),
#  (610, 107348, 3.5),
#  (414, 58839, 2.5),
#  (594, 457, 4.5),
#  (51, 70, 5.0),
#  (382, 165101, 3.5),
#  (274, 1517, 4.0),
#  (249, 115713, 4.5),
#  (233, 115210, 2.0),
#  (105, 6187, 5.0),
#  (469, 2143, 4.0),
#  (418, 6807, 5.0),
#  (282, 6708, 4.0),
#  (311, 466, 1.0),
#  (532, 1240, 4.0),
#  (217, 1077, 2.0),
#  (249, 101525, 4.0),
#  (156, 947, 5.0),
#  (179, 225, 5.0),
#  (438, 216, 3.0),
#  (346, 7371, 4.5),
#  (583, 80549, 4.0),
#  (428, 5952, 3.5),
#  (167, 1748, 4.5),
#  (594, 1307, 5.0),
#  (73, 59315, 4.0),
#  (538, 158, 4.5),
#  (298, 541, 4.5),
#  (477, 3000, 5.0),
#  (453, 1704, 3.0),
#  (144, 2959, 4.0),
#  (420, 2657, 5.0),
#  (221, 296, 5.0),
#  (603, 3505, 3.0),
#  (6, 364, 5.0),
#  (160, 110, 4.0),
#  (372, 497, 4.0),
#  (226, 1407, 4.0),
#  (232, 919, 4.0),
#  (212, 108932, 3.5),
#  (522, 586, 1.0),
#  (563, 40629, 4.0),
#  (514, 81932, 4.0),
#  (573, 63131, 4.0),
#  (436, 349, 3.0),
#  (381, 4571, 3.5),
#  (298, 6059, 2.0),
#  (294, 2375, 1.0),
#  (525, 76093, 4.0),
#  (481, 1721, 5.0),
#  (319, 293, 5.0),
#  (430, 34, 3.0),
#  (420, 3175, 3.5),
#  (50, 32875, 3.0),
#  (357, 3481, 3.0),
#  (597, 1275, 4.0),
#  (222, 19, 3.5),
#  (307, 372, 2.0),
#  (249, 77561, 3.5),
#  (152, 527, 4.5),
#  (117, 160, 3.0),
#  (200, 6377, 4.0),
#  (389, 1356, 5.0),
#  (234, 2422, 2.0),
#  (570, 1682, 3.5),
#  (36, 3766, 2.0),
#  (483, 317, 4.5),
#  (307, 5927, 3.0),
#  (414, 2736, 4.0),
#  (326, 27803, 4.5),
#  (68, 46965, 3.5),
#  (570, 2858, 4.0),
#  (105, 85316, 3.5),
#  (608, 5507, 3.5),
#  (249, 6503, 3.0),
#  (429, 266, 4.0),
#  (339, 72641, 4.5),
#  (318, 63876, 4.0),
#  (448, 72224, 1.0),
#  (309, 1952, 1.5),
#  (306, 95543, 3.0),
#  (32, 788, 1.0),
#  (66, 4572, 4.0),
#  (274, 47518, 3.5),
#  (177, 3052, 4.0),
#  (448, 109187, 2.0),
#  (139, 7454, 1.5),
#  (153, 142488, 3.5),
#  (219, 55292, 1.0),
#  (198, 356, 5.0),
#  (474, 3028, 2.0),
#  (480, 586, 4.0),
#  (610, 61024, 4.0),
#  (245, 2064, 2.0),
#  (200, 5, 4.0),
#  (149, 1375, 2.0),
#  (275, 2324, 5.0),
#  (298, 8531, 2.5),
#  (438, 344, 4.0),
#  (222, 3421, 4.0),
#  (195, 1120, 4.0),
#  (318, 8807, 3.5),
#  (509, 37830, 2.5),
#  (337, 648, 5.0),
#  (18, 30812, 4.0),
#  (387, 8507, 3.0),
#  (222, 3273, 3.0),
#  (437, 194, 4.0),
#  (224, 260, 2.0),
#  (488, 3897, 4.5),
#  (104, 33615, 3.0),
#  (84, 452, 3.0),
#  (20, 2140, 4.0),
#  (365, 145935, 1.5),
#  (336, 2329, 4.5),
#  (177, 69640, 3.5),
#  (263, 5013, 4.5),
#  (284, 303, 4.0),
#  (411, 442, 3.0),
#  (489, 5, 2.0),
#  (274, 6242, 3.0),
#  (580, 1266, 4.0),
#  (380, 6979, 3.0),
#  (318, 1247, 3.0),
#  (349, 10, 4.0),
#  (583, 588, 3.5),
#  (307, 34323, 3.0),
#  (462, 51255, 3.5),
#  (265, 1962, 4.0),
#  (242, 47, 5.0),
#  (28, 51662, 4.5),
#  (586, 112852, 5.0),
#  (219, 3256, 3.0),
#  (163, 1617, 3.0),
#  (426, 63082, 2.5),
#  (40, 353, 3.0),
#  (59, 904, 5.0),
#  (368, 3432, 2.0),
#  (23, 866, 3.0),
#  (517, 2424, 1.5),
#  (571, 1407, 5.0),
#  (6, 594, 4.0),
#  (555, 2076, 3.0),
#  (28, 1095, 3.0),
#  (198, 36, 5.0),
#  (62, 111743, 3.5),
#  (480, 1089, 4.0),
#  (357, 1271, 4.5),
#  (563, 53466, 3.0),
#  (480, 8910, 4.5),
#  (593, 1411, 4.0),
#  (380, 8368, 3.0),
#  (586, 106487, 3.5),
#  (479, 2798, 1.0),
#  (424, 3911, 3.5),
#  (51, 2393, 0.5),
#  (489, 4054, 1.0),
#  (578, 2496, 4.5),
#  (489, 8949, 1.0),
#  (234, 2641, 3.0),
#  (498, 216, 5.0),
#  (181, 378, 3.0),
#  (432, 66203, 3.0),
#  (286, 3481, 3.0),
#  (80, 32, 4.0),
#  (445, 2762, 4.0),
#  (283, 1704, 5.0),
#  (414, 7366, 3.0),
#  (24, 8784, 3.0),
#  (307, 3448, 2.5),
#  (365, 180, 0.5),
#  (64, 2248, 4.0),
#  (249, 6615, 2.0),
#  (590, 1207, 5.0),
#  (292, 59315, 4.5),
#  (414, 81834, 3.5),
#  (590, 2797, 4.5),
#  (372, 1297, 4.0),
#  (58, 186, 3.0),
#  (111, 8531, 3.5),
#  (472, 48516, 5.0),
#  (606, 2353, 3.0),
#  (491, 49286, 4.5),
#  (318, 116823, 2.5),
#  (51, 39183, 5.0),
#  (474, 8961, 4.0),
#  (566, 368, 4.0),
#  (610, 79057, 3.5),
#  (610, 5449, 2.5),
#  (318, 153, 3.0),
#  (262, 322, 3.0),
#  (290, 1299, 4.0),
#  (594, 6975, 0.5),
#  (377, 7756, 5.0),
#  (387, 319, 3.0),
#  (610, 68205, 4.0),
#  (586, 81845, 3.0),
#  (438, 7259, 2.0),
#  (475, 7254, 4.0),
#  (254, 2431, 4.5),
#  (600, 29, 4.5),
#  (551, 91535, 3.5),
#  (448, 66297, 3.0),
#  (438, 317, 3.5),
#  (331, 858, 5.0),
#  (217, 2087, 4.0),
#  (64, 1204, 5.0),
#  (527, 1258, 5.0),
#  (440, 1378, 3.5),
#  (92, 2454, 4.0),
#  (552, 2762, 4.0),
#  (18, 134853, 3.5),
#  (313, 1089, 5.0),
#  (249, 142488, 4.5),
#  (599, 77709, 2.5),
#  (477, 593, 5.0),
#  (288, 31923, 4.0),
#  (174, 32, 3.0),
#  (564, 85367, 4.0),
#  (252, 364, 5.0),
#  (326, 81845, 3.5),
#  (351, 6016, 4.0),
#  (475, 4446, 5.0),
#  (30, 318, 5.0),
#  (353, 256, 3.0),
#  (50, 7748, 4.0),
#  (479, 2362, 4.0),
#  (610, 60069, 4.5),
#  (73, 68358, 5.0),
#  (478, 33794, 4.5),
#  (525, 6218, 3.5),
#  (610, 102338, 4.5),
#  (448, 37727, 2.0),
#  (368, 2405, 2.0),
#  (511, 2324, 4.5),
#  (423, 457, 4.5),
#  (307, 7235, 2.0),
#  (337, 277, 4.0),
#  (603, 3079, 2.0),
#  (139, 7317, 2.0),
#  (444, 235, 5.0),
#  (18, 1608, 3.0),
#  (301, 44191, 2.5),
#  (1, 2012, 4.0),
#  (239, 8798, 4.0),
#  (607, 1625, 5.0),
#  (148, 4308, 4.0),
#  (534, 60072, 3.5),
#  (4, 2973, 2.0),
#  (322, 480, 3.5),
#  (426, 30793, 3.5),
#  (380, 1617, 5.0),
#  (298, 95441, 2.0),
#  (111, 51935, 3.0),
#  (599, 2413, 3.0),
#  (330, 1449, 3.0),
#  (459, 8636, 3.0),
#  (368, 3716, 1.0),
#  (125, 163645, 4.0),
#  (232, 2081, 2.5),
#  (382, 47610, 4.5),
#  (225, 2791, 4.0),
#  (143, 47122, 4.0),
#  (606, 1837, 3.0),
#  (564, 52973, 3.0),
#  (160, 1393, 1.0),
#  (579, 3623, 4.0),
#  (129, 40815, 4.0),
#  (434, 6796, 3.0),
#  (414, 115713, 4.5),
#  (480, 46322, 3.0),
#  (187, 3504, 5.0),
#  (274, 56339, 4.0),
#  (483, 1193, 3.0),
#  (213, 912, 3.5),
#  (169, 1028, 5.0),
#  (561, 145, 3.0),
#  (425, 260, 3.0),
#  (89, 158398, 5.0),
#  (480, 2028, 4.5),
#  (84, 637, 1.0),
#  (410, 1084, 4.0),
#  (608, 543, 3.5),
#  (368, 2278, 3.0),
#  (76, 318, 3.0),
#  (507, 153, 3.0),
#  (409, 3812, 5.0),
#  (45, 1221, 4.0),
#  (122, 93840, 5.0),
#  (606, 1614, 4.0),
#  (606, 2692, 4.5),
#  (356, 1777, 4.5),
#  (567, 106696, 0.5),
#  (517, 137857, 5.0),
#  (608, 522, 0.5),
#  (152, 7156, 4.5),
#  (534, 130520, 4.0),
#  (387, 2632, 4.0),
#  (182, 370, 0.5),
#  (111, 3977, 3.5),
#  (160, 3269, 1.0),
#  (474, 3006, 4.0),
#  (94, 420, 3.0),
#  (555, 1965, 2.0),
#  (275, 608, 4.0),
#  (527, 2455, 5.0),
#  (448, 155820, 1.5),
#  (448, 45499, 3.5),
#  (527, 1196, 5.0),
#  (600, 26712, 4.0),
#  (323, 474, 3.0),
#  (68, 3969, 3.0),
#  (425, 8644, 3.5),
#  (23, 1960, 3.0),
#  (113, 1589, 2.0),
#  (480, 2671, 2.5),
#  (132, 1097, 3.5),
#  (610, 115569, 4.5),
#  (537, 55946, 5.0),
#  (391, 2731, 4.0),
#  (50, 168254, 1.5),
#  (448, 1461, 2.0),
#  (525, 97921, 4.0),
#  (20, 3512, 3.0),
#  (116, 1961, 4.5),
#  (158, 6502, 4.0),
#  (469, 3095, 4.0),
#  (432, 50912, 2.5),
#  (274, 4974, 3.5),
#  (183, 2457, 3.0),
#  (326, 46723, 4.5),
#  (232, 5669, 3.0),
#  (430, 1680, 5.0),
#  (509, 109487, 3.0),
#  (365, 81591, 0.5),
#  (312, 3264, 2.0),
#  (181, 382, 3.0),
#  (266, 2985, 4.0),
#  (199, 11, 4.0),
#  (414, 135, 2.0),
#  (277, 104, 4.0),
#  (414, 1080, 5.0),
#  (514, 1644, 2.0),
#  (232, 45666, 2.0),
#  (328, 317, 2.0),
#  (105, 52281, 5.0),
#  (18, 58295, 3.5),
#  (480, 4270, 3.0),
#  (359, 1277, 4.0),
#  (558, 2987, 4.0),
#  (448, 104218, 1.5),
#  (42, 2997, 4.0),
#  (375, 1586, 3.5),
#  (298, 4228, 3.0),
#  (74, 4973, 5.0),
#  (307, 4448, 4.0),
#  (232, 3147, 5.0),
#  (219, 53972, 4.0),
#  (232, 48412, 3.0),
#  (57, 728, 3.0),
#  (590, 2641, 4.0),
#  (21, 541, 3.5),
#  (34, 6387, 4.5),
#  (43, 102, 5.0),
#  (599, 252, 2.0),
#  (380, 1488, 3.0),
#  (233, 1732, 4.0),
#  (599, 2985, 4.0),
#  (202, 913, 4.0),
#  (249, 1061, 4.0),
#  (64, 3717, 2.5),
#  (436, 231, 1.0),
#  (221, 2915, 3.5),
#  (599, 119218, 2.5),
#  (313, 3753, 3.0),
#  (288, 2117, 2.0),
#  (387, 52604, 2.5),
#  (414, 1073, 4.0),
#  (606, 2283, 3.0),
#  (610, 6502, 5.0),
#  (381, 2987, 3.0),
#  (524, 736, 3.0),
#  (174, 349, 4.0),
#  (610, 4638, 3.0),
#  (475, 116797, 4.5),
#  (610, 112171, 3.5),
#  (453, 3240, 4.0),
#  (68, 8985, 3.5),
#  (171, 1220, 5.0),
#  (599, 1615, 1.5),
#  (20, 3114, 5.0),
#  (500, 4161, 4.0),
#  (581, 4306, 4.5),
#  (198, 50, 5.0),
#  (506, 45447, 0.5),
#  (199, 4370, 3.0),
#  (555, 329, 3.0),
#  (105, 3629, 4.5),
#  (551, 49530, 4.0),
#  (573, 2918, 5.0),
#  (262, 273, 5.0),
#  (91, 3836, 4.5),
#  (283, 63, 3.0),
#  (599, 103609, 1.5),
#  (282, 2468, 3.0),
#  (339, 53000, 4.5),
#  (483, 30707, 4.0),
#  (288, 1024, 2.0),
#  (111, 39, 4.0),
#  (200, 4447, 4.5),
#  (177, 1283, 4.0),
#  (405, 70708, 4.5),
#  (249, 69526, 3.0),
#  (448, 5507, 1.0),
#  (102, 6, 3.0),
#  (160, 2411, 1.0),
#  (438, 6548, 5.0),
#  (474, 25795, 3.5),
#  (475, 52722, 4.5),
#  (448, 108928, 2.5),
#  (294, 260, 5.0),
#  (608, 1215, 3.5),
#  (551, 5418, 4.5),
#  (318, 81191, 4.0),
#  (182, 2067, 4.0),
#  (381, 4270, 3.5),
#  (580, 1784, 4.0),
#  (230, 3578, 3.0),
#  (318, 59315, 3.5),
#  (437, 1197, 4.0),
#  (29, 5464, 4.5),
#  (68, 539, 3.5),
#  (608, 1573, 2.5),
#  (520, 2194, 4.0),
#  (294, 2027, 1.0),
#  (113, 351, 5.0),
#  (145, 344, 2.0),
#  (233, 3977, 3.0),
#  (249, 79592, 3.5),
#  (113, 207, 3.0),
#  (509, 5446, 3.0),
#  (610, 26612, 5.0),
#  (156, 4014, 1.5),
#  (563, 40815, 3.5),
#  (318, 97304, 4.0),
#  (186, 2571, 3.0),
#  (160, 2628, 2.0),
#  (555, 2926, 2.0),
#  (105, 1203, 4.5),
#  (274, 7064, 3.0),
#  (353, 172, 2.0),
#  (20, 986, 3.5),
#  (291, 5816, 5.0),
#  (448, 114060, 3.0),
#  (391, 5339, 4.0),
#  (166, 5418, 4.5),
#  (414, 2020, 5.0),
#  (50, 175707, 3.0),
#  (232, 1608, 3.5),
#  (608, 1918, 3.0),
#  (580, 3703, 4.0),
#  (489, 2953, 0.5),
#  (169, 5873, 4.5),
#  (415, 4308, 3.0),
#  (477, 1103, 3.5),
#  (202, 105, 4.0),
#  (563, 6765, 3.0),
#  (288, 3313, 2.0),
#  (414, 4815, 3.0),
#  (517, 515, 4.0),
#  (103, 3681, 5.0),
#  (288, 3917, 1.0),
#  (298, 4238, 2.5),
#  (307, 1485, 3.0),
#  (17, 2762, 4.0),
#  (89, 42013, 3.0),
#  (182, 2710, 4.5),
#  (599, 72479, 3.5),
#  (431, 543, 3.5),
#  (317, 431, 4.0),
#  (318, 6874, 3.0),
#  (199, 3362, 4.0),
#  (610, 104243, 3.5),
#  (82, 4306, 4.0),
#  (323, 342, 3.0),
#  (42, 3269, 3.0),
#  (464, 60069, 2.0),
#  (590, 4361, 4.5),
#  (432, 3623, 3.0),
#  (606, 5372, 3.5),
#  (104, 1680, 4.0),
#  (503, 81456, 3.0),
#  (305, 3751, 4.0),
#  (274, 6502, 3.5),
#  (352, 1717, 3.0),
#  (289, 594, 3.5),
#  (561, 67734, 3.0),
#  (385, 540, 3.0),
#  (380, 5349, 4.0),
#  (610, 122922, 3.5),
#  (563, 85397, 3.0),
#  (425, 8640, 3.0),
#  (483, 3534, 2.5),
#  (19, 1816, 1.0),
#  (600, 4718, 1.5),
#  (448, 82854, 1.5),
#  (249, 36401, 3.0),
#  (483, 8874, 4.5),
#  (520, 318, 5.0),
#  (474, 40278, 3.5),
#  (298, 135567, 2.5),
#  (103, 59315, 1.5),
#  (122, 3863, 4.5),
#  (380, 6157, 3.0),
#  (590, 673, 3.0),
#  (249, 103624, 4.0),
#  (477, 2407, 3.5),
#  (167, 2791, 4.0),
#  (100, 3499, 2.0),
#  (219, 4025, 0.5),
#  (387, 41716, 2.0),
#  (298, 111743, 0.5),
#  (62, 8529, 4.5),
#  (28, 3556, 3.0),
#  (105, 5956, 4.0),
#  (539, 69122, 5.0),
#  (448, 1755, 4.0),
#  (193, 593, 3.5),
#  (294, 3253, 4.0),
#  (610, 109968, 5.0),
#  (380, 4306, 5.0),
#  (469, 2987, 2.0),
#  (372, 417, 3.0),
#  (387, 53953, 3.0),
#  (517, 1997, 1.0),
#  (445, 4995, 4.0),
#  (590, 3639, 2.5),
#  (570, 1036, 4.0),
#  (414, 5378, 4.0),
#  (387, 3477, 1.5),
#  (525, 27660, 3.0),
#  (140, 1783, 3.0),
#  (42, 2875, 3.0),
#  (306, 135436, 3.5),
#  (491, 3247, 4.5),
#  (513, 920, 5.0),
#  (68, 485, 2.5),
#  (187, 8949, 5.0),
#  (599, 5679, 2.0),
#  (428, 4022, 2.0),
#  (409, 1194, 5.0),
#  (590, 7056, 4.0),
#  (105, 915, 4.0),
#  (599, 53022, 3.0),
#  (129, 6093, 4.5),
#  (288, 3928, 3.5),
#  (517, 4103, 2.0),
#  (140, 6947, 5.0),
#  (84, 14, 4.0),
#  (68, 4378, 2.0),
#  (523, 102407, 5.0),
#  (200, 5225, 4.0),
#  (460, 3615, 3.0),
#  (199, 2289, 5.0),
#  (503, 87413, 3.0),
#  (610, 97306, 3.5),
#  (274, 356, 4.5),
#  (455, 364, 3.0),
#  (380, 8947, 3.0),
#  (599, 5618, 2.5),
#  (292, 8368, 4.0),
#  (6, 434, 4.0),
#  (460, 2762, 4.5),
#  (448, 6708, 3.5),
#  (414, 173205, 4.0),
#  (483, 5570, 3.0),
#  (590, 44665, 3.5),
#  (4, 2770, 2.0),
#  (514, 3253, 4.0),
#  (26, 185, 3.0),
#  (288, 2857, 3.0),
#  (474, 1797, 4.0),
#  (486, 163, 4.0),
#  (305, 1270, 5.0),
#  (63, 111781, 5.0),
#  (348, 5291, 4.5),
#  (140, 1019, 4.0),
#  (306, 161634, 3.5),
#  (348, 3083, 4.5),
#  (530, 454, 5.0),
#  (420, 1281, 4.0),
#  (539, 6753, 4.5),
#  (217, 1855, 3.0),
#  (606, 3067, 4.5),
#  (105, 935, 4.0),
#  (387, 7116, 3.5),
#  (414, 2580, 5.0),
#  (428, 4446, 3.5),
#  (334, 1136, 4.0),
#  (509, 98243, 3.5),
#  (548, 2571, 5.0),
#  (239, 4886, 4.5),
#  (104, 2355, 4.0),
#  (274, 49272, 4.0),
#  (453, 300, 5.0),
#  (546, 2456, 2.0),
#  (596, 96079, 3.0),
#  (61, 2174, 3.5),
#  (115, 2028, 5.0),
#  (84, 31, 3.0),
#  (509, 4878, 4.0),
#  (144, 6591, 3.5),
#  (256, 1198, 5.0),
#  (415, 150, 4.0),
#  (89, 8978, 2.5),
#  (589, 161, 3.0),
#  (21, 2953, 3.0),
#  (412, 2763, 4.0),
#  (24, 96079, 3.5),
#  (570, 1784, 4.0),
#  (288, 2100, 4.0),
#  (608, 1707, 1.0),
#  (385, 534, 3.0),
#  (387, 26258, 3.5),
#  (274, 609, 4.0),
#  (7, 5464, 3.0),
#  (294, 1356, 4.0),
#  (608, 1101, 3.0),
#  (103, 5103, 4.0),
#  (240, 276, 5.0),
#  (537, 105504, 5.0),
#  (592, 21, 3.0),
#  (40, 110, 4.0),
#  (20, 4367, 0.5),
#  (610, 44397, 3.5),
#  (177, 7163, 2.0),
#  (344, 34150, 4.0),
#  (306, 59258, 3.0),
#  (318, 8873, 4.0),
#  (477, 41569, 4.0),
#  (534, 103249, 4.0),
#  (156, 62, 2.0),
#  (599, 3950, 2.5),
#  (414, 105504, 4.0),
#  (187, 290, 4.0),
#  (271, 4370, 3.0),
#  (610, 4270, 3.0),
#  (298, 78209, 3.5),
#  (414, 372, 4.0),
#  (111, 4896, 4.0),
#  (514, 356, 4.0),
#  (177, 54276, 3.0),
#  (448, 2410, 3.0),
#  (156, 2300, 4.0),
#  (288, 4016, 4.0),
#  (387, 1952, 4.0),
#  (140, 3098, 4.0),
#  (462, 5288, 4.0),
#  (380, 56801, 2.0),
#  (68, 64969, 5.0),
#  (153, 64034, 1.0),
#  (448, 134021, 2.5),
#  (40, 592, 4.0),
#  (178, 454, 4.5),
#  (274, 104, 3.5),
#  (525, 116823, 3.0),
#  (599, 61240, 3.5),
#  (474, 6870, 3.5),
#  (599, 64030, 2.0),
#  (368, 2412, 2.0),
#  (588, 10, 3.0),
#  (520, 1527, 3.5),
#  (424, 91658, 3.5),
#  (50, 102407, 2.5),
#  (599, 6909, 2.5),
#  (211, 296, 4.5),
#  (140, 4855, 4.0),
#  (497, 2762, 5.0),
#  (514, 3938, 2.0),
#  (560, 66097, 3.5),
#  (414, 53468, 2.5),
#  (603, 1617, 5.0),
#  (346, 319, 2.5),
#  (469, 592, 3.0),
#  (330, 1136, 4.5),
#  (125, 7361, 4.5),
#  (73, 101612, 3.0),
#  (586, 122896, 5.0),
#  (606, 44759, 2.5),
#  (452, 4299, 4.0),
#  (440, 193, 3.5),
#  (89, 170993, 4.0),
#  (294, 2380, 3.0),
#  (260, 3052, 4.5),
#  (307, 50, 4.5),
#  (172, 1270, 4.0),
#  (246, 68157, 5.0),
#  (105, 5995, 4.0),
#  (599, 487, 2.0),
#  (58, 780, 5.0),
#  (177, 4896, 5.0),
#  (106, 5218, 3.5),
#  (414, 5446, 3.5),
#  (217, 419, 2.0),
#  (6, 318, 5.0),
#  (604, 426, 3.0),
#  (608, 1954, 4.5),
#  (305, 85788, 2.0),
#  (380, 5804, 3.0),
#  (48, 3623, 2.5),
#  (413, 4262, 5.0),
#  (369, 2046, 3.0),
#  (27, 1304, 3.0),
#  (249, 33493, 4.0),
#  (599, 2380, 1.0),
#  (474, 4160, 4.5),
#  (260, 5971, 4.5),
#  (474, 2501, 3.5),
#  (610, 56145, 4.5),
#  (91, 2628, 4.0),
#  (289, 1220, 3.5),
#  (141, 4018, 3.5),
#  (292, 1580, 4.0),
#  (401, 364, 3.5),
#  (313, 367, 2.0),
#  (11, 170, 4.0),
#  (380, 1270, 5.0),
#  (414, 4018, 3.0),
#  (169, 3755, 4.0),
#  (567, 7301, 3.5),
#  (599, 176419, 3.5),
#  (232, 48394, 3.0),
#  (380, 1806, 3.0),
#  (19, 2463, 2.0),
#  (292, 90249, 3.5),
#  (477, 1889, 4.0),
#  (125, 175303, 3.0),
#  (111, 6952, 0.5),
#  (608, 2321, 3.5),
#  (573, 4022, 3.5),
#  (337, 24, 5.0),
#  (300, 2329, 4.0),
#  (305, 118706, 4.0),
#  (50, 143859, 2.0),
#  (561, 2378, 3.5),
#  (600, 1732, 3.5),
#  (166, 3793, 3.5),
#  (484, 4034, 4.5),
#  (263, 4959, 3.0),
#  (599, 210, 2.0),
#  (21, 5219, 3.0),
#  (599, 103027, 3.0),
#  (610, 130634, 4.5),
#  (355, 60, 3.0),
#  (514, 1976, 2.0),
#  (492, 673, 5.0),
#  (57, 552, 2.0),
#  (274, 29, 4.0),
#  (83, 5010, 4.0),
#  (397, 5650, 2.5),
#  (469, 1200, 4.0),
#  (438, 1831, 3.0),
#  (140, 4265, 2.0),
#  (483, 293, 4.0),
#  (594, 4794, 0.5),
#  (384, 2908, 2.0),
#  (68, 434, 3.0),
#  (387, 4833, 2.5),
#  (424, 1784, 3.5),
#  (463, 1552, 4.5),
#  (318, 49278, 3.5),
#  (240, 519, 3.0),
#  (159, 56367, 5.0),
#  (202, 306, 5.0),
#  (307, 2908, 1.0),
#  (414, 2598, 2.0),
#  (24, 3578, 4.0),
#  (474, 345, 3.5),
#  (318, 71106, 3.0),
#  (600, 33794, 2.5),
#  (414, 4718, 5.0),
#  (590, 2022, 3.5),
#  (325, 1784, 4.0),
#  (220, 5872, 1.0),
#  (414, 48161, 3.0),
#  (74, 5300, 4.0),
#  (217, 1333, 3.0),
#  (195, 1958, 4.0),
#  (609, 1, 3.0),
#  (590, 3468, 4.5),
#  (474, 4347, 4.0),
#  (32, 78, 4.0),
#  (7, 38388, 3.5),
#  (414, 2328, 2.0),
#  ...]

# %%
algo.predict(353, 904)
# Out:
# Prediction(uid=353, iid=904, r_ui=None, est=4.3997351048638, details={'actual_k': 40, 'was_impossible': False})

# %%
algo.get_neighbors(353, 40)
# Out:
# [11,
#  19,
#  30,
#  37,
#  41,
#  49,
#  52,
#  54,
#  57,
#  61,
#  62,
#  65,
#  67,
#  72,
#  74,
#  75,
#  87,
#  92,
#  97,
#  104,
#  115,
#  116,
#  124,
#  126,
#  133,
#  134,
#  138,
#  142,
#  149,
#  152,
#  158,
#  164,
#  165,
#  167,
#  170,
#  172,
#  176,
#  177,
#  185,
#  196]

# %%
algo.predict(algo.trainset.to_inner_uid(292), algo.trainset.to_inner_iid(164909))
# Out:
# Prediction(uid=169, iid=3542, r_ui=None, est=3.500216938562999, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'})

# %%
algo.get_neighbors(iid=algo.trainset.to_inner_uid(353), k=5)
# Out:
# [10, 37, 52, 66, 74]

# %%
pd.merge(df[df['userId']==353], df[df['userId']==algo.trainset.to_raw_uid(87)], on='movieId')
# Out:
#     userId_x  movieId  rating_x                                title_x  \
# 0        353        1       5.0                       Toy Story (1995)
# 1        353       70       4.0             From Dusk Till Dawn (1996)
# 2        353      110       3.0                      Braveheart (1995)
# 3        353      216       3.0                   Billy Madison (1995)
# 4        353      296       5.0                    Pulp Fiction (1994)
# 5        353      367       3.0                       Mask, The (1994)
# 6        353      590       4.0              Dances with Wolves (1990)
# 7        353      593       5.0       Silence of the Lambs, The (1991)
# 8        353      318       5.0       Shawshank Redemption, The (1994)
# 9        353      595       4.0            Beauty and the Beast (1991)
# 10       353       34       5.0                            Babe (1995)
# 11       353      344       5.0      Ace Ventura: Pet Detective (1994)
# 12       353      364       4.0                  Lion King, The (1994)
# 13       353        2       4.0                         Jumanji (1995)
# 14       353        5       3.0     Father of the Bride Part II (1995)
# 15       353       19       4.0  Ace Ventura: When Nature Calls (1995)
# 16       353      158       3.0                          Casper (1995)
# 17       353      555       4.0                    True Romance (1993)
#
#     userId_y  rating_y                                title_y
# 0        103       4.0                       Toy Story (1995)
# 1        103       3.5             From Dusk Till Dawn (1996)
# 2        103       4.5                      Braveheart (1995)
# 3        103       4.0                   Billy Madison (1995)
# 4        103       5.0                    Pulp Fiction (1994)
# 5        103       3.5                       Mask, The (1994)
# 6        103       4.0              Dances with Wolves (1990)
# 7        103       5.0       Silence of the Lambs, The (1991)
# 8        103       5.0       Shawshank Redemption, The (1994)
# 9        103       3.0            Beauty and the Beast (1991)
# 10       103       4.0                            Babe (1995)
# 11       103       3.5      Ace Ventura: Pet Detective (1994)
# 12       103       3.0                  Lion King, The (1994)
# 13       103       4.0                         Jumanji (1995)
# 14       103       4.0     Father of the Bride Part II (1995)
# 15       103       3.5  Ace Ventura: When Nature Calls (1995)
# 16       103       3.5                          Casper (1995)
# 17       103       5.0                    True Romance (1993)

# %%
def get_votes_for_film_user(uid, iid):
    neighbors = algo.get_neighbors(iid=algo.trainset.to_inner_uid(uid), k=40)
    for n in neighbors:
        res = df_ratings[(df_ratings['userId'] == n) & (df_ratings['movieId'] == iid)]
        print (n, res['rating'].tolist()[0] if len(res['rating'].tolist()) > 0 else "None")

# %%
get_votes_for_film_user(353, 1)
# Out:
# 10 None
# 37 None
# 52 None
# 66 4.0
# 74 None
# 86 4.0
# 96 5.0
# 99 None
# 104 None
# 116 None
# 120 None
# 136 None
# 137 4.0
# 157 None
# 165 None
# 167 3.5
# 182 4.0
# 185 4.0
# 203 None
# 210 None
# 212 None
# 226 3.5
# 242 None
# 250 None
# 267 None
# 276 4.0
# 277 4.0
# 279 3.0
# 287 None
# 297 None
# 305 None
# 306 None
# 314 3.0
# 327 None
# 337 4.0
# 339 4.0
# 347 5.0
# 348 None
# 351 None
# 353 5.0

# %%
algo.predict(353, 1)
# Out:
# Prediction(uid=353, iid=1, r_ui=None, est=4.112634892631316, details={'actual_k': 40, 'was_impossible': False})

# %% [markdown]
# ## Item-based рекомендация

# %%
algo = KNNBasic(k=40, sim_options={'name': 'pearson_baseline', 'user_based': False})

# %%
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
predictions = algo.test(testset)

# %%
accuracy.mae(predictions)
# Out:
# MAE:  0.6925
# 0.6925000175547114

# %%
from surprise import KNNWithMeans

# %%
algo = KNNWithMeans(k=40, sim_options={'name': 'pearson_baseline', 'user_based': False})

# %%
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
predictions = algo.test(testset)

# %%
accuracy.mae(predictions)
# Out:
# MAE:  0.6674
# 0.6673617427252511

# %%
df_ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 5            1       70     3.0   964982400
# 6            1      101     5.0   964980868
# 7            1      110     4.0   964982176
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# 10           1      163     5.0   964983650
# 11           1      216     5.0   964981208
# 12           1      223     3.0   964980985
# 13           1      231     5.0   964981179
# 14           1      235     4.0   964980908
# 15           1      260     5.0   964981680
# 16           1      296     3.0   964982967
# 17           1      316     3.0   964982310
# 18           1      333     5.0   964981179
# 19           1      349     4.0   964982563
# 20           1      356     4.0   964980962
# 21           1      362     5.0   964982588
# 22           1      367     4.0   964981710
# 23           1      423     3.0   964982363
# 24           1      441     4.0   964980868
# 25           1      457     5.0   964981909
# 26           1      480     4.0   964982346
# 27           1      500     3.0   964981208
# 28           1      527     5.0   964984002
# 29           1      543     4.0   964981179
# ...        ...      ...     ...         ...
# 100806     610   150401     3.0  1479543210
# 100807     610   152077     4.0  1493845817
# 100808     610   152081     4.0  1493846503
# 100809     610   152372     3.5  1493848841
# 100810     610   155064     3.5  1493848456
# 100811     610   156371     5.0  1479542831
# 100812     610   156726     4.5  1493848444
# 100813     610   157296     4.0  1493846563
# 100814     610   158238     5.0  1479545219
# 100815     610   158721     3.5  1479542491
# 100816     610   158872     3.5  1493848024
# 100817     610   158956     3.0  1493848947
# 100818     610   159093     3.0  1493847704
# 100819     610   160080     3.0  1493848031
# 100820     610   160341     2.5  1479545749
# 100821     610   160527     4.5  1479544998
# 100822     610   160571     3.0  1493848537
# 100823     610   160836     3.0  1493844794
# 100824     610   161582     4.0  1493847759
# 100825     610   161634     4.0  1493848362
# 100826     610   162350     3.5  1493849971
# 100827     610   163937     3.5  1493848789
# 100828     610   163981     3.5  1493850155
# 100829     610   164179     5.0  1493845631
# 100830     610   166528     4.0  1493879365
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
similar_films = algo.get_neighbors(algo.trainset.to_inner_iid(1), k=10)

# %%
similar_films = [algo.trainset.to_raw_iid(i) for i in similar_films]

# %%
similar_films
# Out:
# [588, 3114, 8961, 6377, 1270, 2716, 2115, 34, 8636, 1097]

# %%
df_movies[df_movies['movieId'].isin(similar_films)]
# Out:
#       movieId                                        title  \
# 32         34                                  Babe (1995)
# 506       588                               Aladdin (1992)
# 836      1097            E.T. the Extra-Terrestrial (1982)
# 969      1270                    Back to the Future (1985)
# 1576     2115  Indiana Jones and the Temple of Doom (1984)
# 2038     2716   Ghostbusters (a.k.a. Ghost Busters) (1984)
# 2355     3114                           Toy Story 2 (1999)
# 4360     6377                          Finding Nemo (2003)
# 5260     8636                          Spider-Man 2 (2004)
# 5374     8961                      Incredibles, The (2004)
#
#                                            genres
# 32                                 Children|Drama
# 506   Adventure|Animation|Children|Comedy|Musical
# 836                         Children|Drama|Sci-Fi
# 969                       Adventure|Comedy|Sci-Fi
# 1576                     Action|Adventure|Fantasy
# 2038                         Action|Comedy|Sci-Fi
# 2355  Adventure|Animation|Children|Comedy|Fantasy
# 4360          Adventure|Animation|Children|Comedy
# 5260                 Action|Adventure|Sci-Fi|IMAX
# 5374   Action|Adventure|Animation|Children|Comedy

# %%
from surprise.model_selection import KFold

# %%
kfold = KFold(5)

# %%
scores = []
for trainset, testset in tqdm_notebook(kfold.split(dataset)):
    algo = KNNWithMeans(k=40, sim_options={'name': 'pearson_baseline', 'user_based': False})
    algo.fit(trainset)
    predictions = algo.test(testset)
    scores.append(accuracy.mae(predictions))
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# MAE:  0.6703
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# MAE:  0.6723
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# MAE:  0.6694
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# MAE:  0.6713
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# MAE:  0.6663

# %%
scores
# Out:
# [0.6702720954252053,
#  0.6723209317479646,
#  0.669376474555652,
#  0.6713177935709984,
#  0.6663283086935524]
