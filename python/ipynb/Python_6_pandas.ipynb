# %% [markdown]
# # Функции в Pandas

# %%
import pandas as pd

# %%
stats = pd.read_excel('../data/ad_campaigns.xlsx')
stats.head()
# Out:
#      Название группы                            Фраза (с минус-словами)  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    Продуктивность  ID объявления                      Заголовок  \
# 0             4.5     2101704995  МРТ на Менделеевской от 2000₽
# 1             4.5     2101704995  МРТ на Менделеевской от 2000₽
# 2             7.4     2101704995  МРТ на Менделеевской от 2000₽
# 3             5.0     2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4             5.0     2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                Текст  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                               Ссылка
# 0  https://awesome-site.ru/?utm_source=yandex&utm...
# 1  https://awesome-site.ru/?utm_source=yandex&utm...
# 2  https://awesome-site.ru/?utm_source=yandex&utm...
# 3  https://awesome-site.ru/?utm_source=yandex&utm...
# 4  https://awesome-site.ru/?utm_source=yandex&utm...

# %%
# ?stats.rename
# Out:
# Signature: stats.rename(mapper=None, index=None, columns=None, axis=None, copy=True, inplace=False, level=None)
# Docstring:
# Alter axes labels.
#
# Function / dict values must be unique (1-to-1). Labels not contained in
# a dict / Series will be left as-is. Extra labels listed don't throw an
# error.
#
# See the :ref:`user guide <basics.rename>` for more.
#
# Parameters
# ----------
# mapper, index, columns : dict-like or function, optional
#     dict-like or functions transformations to apply to
#     that axis' values. Use either ``mapper`` and ``axis`` to
#     specify the axis to target with ``mapper``, or ``index`` and
#     ``columns``.
# axis : int or str, optional
#     Axis to target with ``mapper``. Can be either the axis name
#     ('index', 'columns') or number (0, 1). The default is 'index'.
# copy : boolean, default True
#     Also copy underlying data
# inplace : boolean, default False
#     Whether to return a new DataFrame. If True then value of copy is
#     ignored.
# level : int or level name, default None
#     In case of a MultiIndex, only rename labels in the specified
#     level.
#
# Returns
# -------
# renamed : DataFrame
#
# See Also
# --------
# pandas.DataFrame.rename_axis
#
# Examples
# --------
#
# ``DataFrame.rename`` supports two calling conventions
#
# * ``(index=index_mapper, columns=columns_mapper, ...)``
# * ``(mapper, axis={'index', 'columns'}, ...)``
#
# We *highly* recommend using keyword arguments to clarify your
# intent.
#
# >>> df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})
# >>> df.rename(index=str, columns={"A": "a", "B": "c"})
#    a  c
# 0  1  4
# 1  2  5
# 2  3  6
#
# >>> df.rename(index=str, columns={"A": "a", "C": "c"})
#    a  B
# 0  1  4
# 1  2  5
# 2  3  6
#
# Using axis-style parameters
#
# >>> df.rename(str.lower, axis='columns')
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6
#
# >>> df.rename({1: 2, 2: 4}, axis='index')
#    A  B
# 0  1  4
# 2  2  5
# 4  3  6
# File:      ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py
# Type:      method

# %%
stats.columns = ['group', 'phrase', 'effect', 'ad_id', 'title', 'text', 'link']
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link
# 0  https://awesome-site.ru/?utm_source=yandex&utm...
# 1  https://awesome-site.ru/?utm_source=yandex&utm...
# 2  https://awesome-site.ru/?utm_source=yandex&utm...
# 3  https://awesome-site.ru/?utm_source=yandex&utm...
# 4  https://awesome-site.ru/?utm_source=yandex&utm...

# %% [markdown]
# ### Lambda-функции
# Хотим посчитать распределение количества слов в столбце с фразами

# %%
stats['word_count'] = stats['phrase'].apply(lambda x: len(x.split(' ')))
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2

# %%
# вариант с передачей всей строчки функции
# тут надо обязательно указать параметр axis = 1

stats['word_count'] = stats.apply(lambda x: len(x['phrase'].split(' ')), axis=1)
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2

# %%
stats['word_count'].value_counts()
# Out:
# 3     1129
# 4      529
# 2      189
# 5      137
# 6       84
# 7       38
# 8       30
# 9       12
# 10       6
# 12       2
# 21       1
# 17       1
# 11       1
# Name: word_count, dtype: int64

# %%
# %matplotlib inline

# %%
stats['word_count'].hist()

# %%
stats['word_count'].hist(bins=30)

# %% [markdown]
# ### Упражнение
# Поисковые запросы с каким количеством слов встречаются в наших данных чаще всего? Выведите топ-5

# %%
stats['word_count'].value_counts().head(5)
# Out:
# 3    1129
# 4     529
# 2     189
# 5     137
# 6      84
# Name: word_count, dtype: int64

# %% [markdown]
# ### Произвольные функции
# В URL кампаний есть названия. С этим надо что-то делать

# %%
# пример ссылки
url = stats.loc[0, 'link']
url
# Out:
# 'https://awesome-site.ru/?utm_source=yandex&utm_medium=cpc&utm_campaign=a825749b87&utm_content=dev_{device_type}'

# %%
from urllib import parse

# %%
parsed = parse.urlsplit(url)
parsed
# Out:
# SplitResult(scheme='https', netloc='awesome-site.ru', path='/', query='utm_source=yandex&utm_medium=cpc&utm_campaign=a825749b87&utm_content=dev_{device_type}', fragment='')

# %%
# можно конечно вручную
parsed.query.split('&')[2].split('=')[1]
# Out:
# 'a825749b87'

# %%
# как доставать значения

parsed.netloc
# Out:
# 'awesome-site.ru'

# %%
params = parse.parse_qs(parsed.query)
params
# Out:
# {'utm_source': ['yandex'],
#  'utm_medium': ['cpc'],
#  'utm_campaign': ['a825749b87'],
#  'utm_content': ['dev_{device_type}']}

# %%
# вот и кампании

params['utm_campaign'][0]
# Out:
# 'a825749b87'

# %%
# зачем тут везде списки?

url_with_doubles = 'https://awesome-site.ru/?a=1&a=2&a=3'

parsed = parse.urlsplit(url_with_doubles)
parse.parse_qs(parsed.query)
# Out:
# {'a': ['1', '2', '3']}

# %%
# оборачиваем все в функцию
# в качестве аргумента будет строка датафрейма

def campaign_name(row):
    """Получение названия кампании из ссылки внутри строки row"""

    parsed = parse.urlsplit(row['link'])
    params_dict = parse.parse_qs(parsed.query)

    return params_dict['utm_campaign'][0]

# %%
stats['campaign'] = stats.apply(campaign_name, axis=1)
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count    campaign
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2  a825749b87
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2  a825749b87
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6  a825749b87
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2  9cc0c5f6ca
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2  9cc0c5f6ca

# %%
# как передать несколько аргументов

def power_up(row, n):
    """Возводит значение столбца effect в степень n"""
    return row['effect'] ** n

# %%
stats['power_up'] = stats.apply(power_up, n=3, axis=1)
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count    campaign  \
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2  a825749b87
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2  a825749b87
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6  a825749b87
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2  9cc0c5f6ca
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2  9cc0c5f6ca
#
#    power_up
# 0    91.125
# 1    91.125
# 2   405.224
# 3   125.000
# 4   125.000

# %% [markdown]
# ### Упражнение
# В наших данных есть много объявлений с услугой МРТ (в названии группы есть слово 'мрт') круглосуточно (в тексте объявления есть '24 часа'). Выделите строки, в которых не упоминается МРТ, но прием идет круглосуточно. Сколько таких строк в датасете?

# %%
def split_phrase(row):
    return True if ('24 часа' in row['text']) and ('мрт' not in row['phrase']) else False
stats['check'] = stats.apply(split_phrase, axis=1)

# %%
stats
# Out:
#                              group  \
# 0                мрт менделеевская
# 1                          мрт цао
# 2                          мрт цао
# 3                          мрт цао
# 4                          мрт сао
# 5                          мрт сао
# 6                          мрт сао
# 7               мрт в москве в сао
# 8               мрт в москве в сао
# 9               мрт в москве в сао
# 10              цмрт менделеевская
# 11                  цмрт стромынка
# 12                 цмрт сокольники
# 13                     мрт орехово
# 14                     мрт орехово
# 15                     мрт орехово
# 16                     мрт щелково
# 17                     мрт щелково
# 18                     мрт щелково
# 19                  мрт домодедово
# 20                  мрт домодедово
# 21                  мрт домодедово
# 22               мрт на павелецкой
# 23               мрт на павелецкой
# 24               мрт на павелецкой
# 25             мрт на алексеевской
# 26             мрт на алексеевской
# 27             мрт на алексеевской
# 28                     мрт куркино
# 29                     мрт куркино
# ...                            ...
# 2129          сделать мрт в москве
# 2130              мрт центр москва
# 2131  мрт на кутузовском проспекте
# 2132  мрт на кутузовском проспекте
# 2133   круглосуточный мрт в москве
# 2134   круглосуточный мрт в москве
# 2135   круглосуточный мрт в москве
# 2136               мрт на шолохова
# 2137               мрт на шолохова
# 2138        инвитро мрт на каширке
# 2139        инвитро мрт на каширке
# 2140        инвитро мрт на каширке
# 2141         мрт в северном бутово
# 2142         мрт в северном бутово
# 2143         мрт в северном бутово
# 2144        мрт склифосовский цена
# 2145        мрт склифосовский цена
# 2146        мрт склифосовский цена
# 2147              11 мрт стромынка
# 2148              11 мрт стромынка
# 2149              11 мрт стромынка
# 2150           цмрт новослободская
# 2151                      мрт вднх
# 2152                      мрт вднх
# 2153                      мрт вднх
# 2154                    мрт палиха
# 2155            клиника москва мрт
# 2156            клиника москва мрт
# 2157            клиника москва мрт
# 2158                 10 мрт палиха
#
#                                                  phrase  effect       ad_id  \
# 0                                 "!мрт !менделеевская"     4.5  2101704995
# 1                                   "мрт менделеевская"     4.5  2101704995
# 2     мрт менделеевская -головы -позвоночника -сдела...     7.4  2101704995
# 3                                           "!мрт !цао"     5.0  2101704999
# 4                                             "мрт цао"     5.0  2101704999
# 5          мрт цао -головы -позвоночника -сделать -цена     7.4  2101704999
# 6                                             "мрт сао"     5.5  2101705000
# 7                                           "!мрт !сао"     5.5  2101705000
# 8     мрт сао -головы -москве -позвоночника -сделать...     7.4  2101705000
# 9                                    "мрт в москве сао"     6.5  2101705001
# 10                                   мрт в москве в сао     8.5  2101705001
# 11                                "!мрт в !москве !сао"     5.0  2101705001
# 12                                   цмрт менделеевская     3.3  2101705003
# 13                                       цмрт стромынка     5.8  2101705006
# 14                                      цмрт сокольники     6.6  2101705008
# 15                                        "мрт орехово"     4.9  2101705009
# 16                                      "!мрт !орехово"     4.9  2101705009
# 17    мрт орехово -головы -зуево -метро -позвоночник...     6.7  2101705009
# 18                                        "мрт щелково"     6.8  2101705011
# 19                                      "!мрт !щелково"     6.8  2101705011
# 20     мрт щелково -головы -позвоночника -сделать -цена     6.6  2101705011
# 21                                     "мрт домодедово"     6.8  2101705020
# 22                                   "!мрт !домодедово"     6.8  2101705020
# 23    мрт домодедово -головы -позвоночника -сделать ...     6.5  2101705020
# 24                                  "мрт на павелецкой"     7.6  2101705029
# 25                               "!мрт !на !павелецкой"     7.6  2101705029
# 26    мрт на павелецкой -головы -круглосуточно -метр...     6.3  2101705029
# 27                                "мрт на алексеевской"     7.5  2101705038
# 28                             "!мрт !на !алексеевской"     7.5  2101705038
# 29    мрт на алексеевской -головы -м -метро -мытищин...     6.3  2101705038
# ...                                                 ...     ...         ...
# 2129                     "мрт в одинцово адреса и цены"     6.6  3200467945
# 2130                                мрт москва 3 -тесла     3.6  3401169381
# 2131  сделать мрт в москве -где -головы -дешевле -ка...     8.1  3401169397
# 2132                  мрт центр москва -диагностическая     8.5  3401169402
# 2133                     "мрт на кутузовском проспекте"     6.7  3826704842
# 2134                 "!мрт !на !кутузовском !проспекте"     6.7  3826704842
# 2135                        круглосуточный мрт в москве     7.4  3826704844
# 2136                      "круглосуточный мрт в москве"     6.6  3826704844
# 2137                  "!круглосуточный !мрт !в !москве"     1.8  3826704844
# 2138                            "!мрт !на !шолохова !5"     3.7  3826704846
# 2139                                "мрт на шолохова 5"     3.7  3826704846
# 2140                             инвитро мрт на каширке     7.6  3826704849
# 2141                       "!инвитро !мрт !на !каширке"     6.6  3826704849
# 2142                           "инвитро мрт на каширке"     6.6  3826704849
# 2143                              мрт в северном бутово     7.5  3826704851
# 2144                            "мрт в северном бутово"     6.8  3826704851
# 2145                        "!мрт !в !северном !бутово"     6.8  3826704851
# 2146                             мрт склифосовский цена     7.8  3826704853
# 2147                        "!мрт !склифосовский !цена"     3.0  3826704853
# 2148                           "мрт склифосовский цена"     5.4  3826704853
# 2149                              "!11 !мрт !стромынка"     7.8  3826704855
# 2150                                 "11 мрт стромынка"     7.8  3826704855
# 2151               11 мрт стромынка -сокольники -центры     7.7  3826704855
# 13    7b17b2d188   195.112  False
# 14    da872d1fb4   287.496  False
# 15    7f35591a28   117.649  False
# 16    7f35591a28   117.649  False
# 17    7f35591a28   300.763  False
# 18    7f35591a28   314.432  False
# 19    7f35591a28   314.432  False
# 20    7f35591a28   287.496  False
# 21    7f35591a28   314.432  False
# 22    7f35591a28   314.432  False
# 23    7f35591a28   274.625  False
# 24    7f35591a28   438.976  False
# 25    7f35591a28   438.976  False
# 26    7f35591a28   250.047  False
# 27    7f35591a28   421.875  False
# 28    7f35591a28   421.875  False
# 29    7f35591a28   250.047  False
# ...          ...       ...    ...
# 2129  942cf4ac20   287.496  False
# 2130  d5b16c7769    46.656  False
# 2131  2cc2e7d770   531.441  False
# 2132  eb577faed1   614.125  False
# 2133  7f35591a28   300.763  False
# 2134  7f35591a28   300.763  False
# 2135  d96029561c   405.224  False
# 2136  d96029561c   287.496  False
# 2137  d96029561c     5.832  False
# 2138  7f35591a28    50.653  False
# 2139  7f35591a28    50.653  False
# 2140  8e77a0e565   438.976  False
# 2141  8e77a0e565   287.496  False
# 2142  8e77a0e565   287.496  False
# 2143  8e77a0e565   421.875  False
# 2144  8e77a0e565   314.432  False
# 2145  8e77a0e565   314.432  False
# 2146  92de552c53   474.552  False
# 2147  92de552c53    27.000  False
# 2148  92de552c53   157.464  False
# 2149  9ee3e2c876   474.552  False
# 2150  9ee3e2c876   474.552  False
# 2151  9ee3e2c876   456.533  False
# 2152  b3f52e6f64   421.875  False
# 2153  9bf072c32b   405.224  False
# 2154  9bf072c32b   405.224  False
# 2155  9bf072c32b   373.248  False
# 2156  a117c5fc1b   405.224  False
# 2157  23d6da5a5a   658.503  False
# 2158  23d6da5a5a   658.503  False
#
# [2159 rows x 11 columns]

# %%
stats['check'].value_counts()
# Out:
# False    2120
# True       39
# Name: check, dtype: int64

# %% [markdown]
# # Группировки

# %%
# этот value_counts уже всех достал

stats['campaign'].value_counts().head()

# %%
# нужно что-то более универсальное

stats.groupby('campaign').count().head()

# %%
stats.groupby('campaign').count()[['group', 'effect']]

# %%
stats.index.values

# %%
stats.groupby('campaign').count().reset_index()

# %%
# тоже самое, что с value_counts

stats.groupby('campaign').count().reset_index().sort_values('group', ascending=False).head()

# %%
# но теперь можно менять функции ура

stats.groupby('campaign').sum().sort_values('effect').head()

# %% [markdown]
# ### Упражнение
# Для каждой кампании campaign найдите минимальное значение столбца effect и постройте рейтинг кампаний по этим значениям, начиная с самого низкого.

# %% [markdown]
# ### Несколько функций в группировках

# %%
# задаем несколько функций сразу

stats.groupby('campaign').agg(['min', 'max'])['effect'].head()

# %%
# разные метрики для разных столбцов

stats.groupby('campaign').agg({'effect': ['min', 'max'], 'power_up': 'mean'}).head()

# %%
# группировка по нескольким столбцам

stats.groupby(['group', 'campaign']).count().head()

# %%
# максимальное число объявлений в одной группе

stats.groupby(['group', 'campaign']).count().sort_values('phrase', ascending=False).head()

# %% [markdown]
# ### Упражнение
# Какая кампания имеет наименьшую сумму по столбцу effect?

# %% [markdown]
# # Агрегированные группировки
# Считаем метрики для пользователей, которые выставили 100 и более оценок

# %%
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratings.head()

# %% [markdown]
# ### Упражнение
# Получите список пользователей film_fans_user_ids, которые выставили 100 и более оценок фильмам. Чтобы перевести pandas series в список можно использовать метод tolist():
#
# film_fans_user_ids = some_dataframe['userId'].tolist()

# %%
ratings.groupby('userId').count().head()

# %%
ratings_filtered[.... > 100]

# %%
ratings_filtered['userId'].tolist()

# %%
ratings[ ratings['userId'].isin(...) ]

# %% [markdown]
# # Сводные таблицы
# Прям как в экселе

# %%
data = pd.read_csv('ml-latest-small/ratings.csv')
data.head()

# %%
# какие оценки поставил пользователь №1

data[ data['userId'] == 1 ]['rating'].value_counts()

# %%
# а для всех пользователей сразу?

data.pivot_table(index = 'userId', columns = 'rating', values = 'timestamp', aggfunc = 'count', fill_value = 0)

# %%
# можно итоги добавить
data.pivot_table(index = 'userId', columns = 'rating', values = 'timestamp', aggfunc = 'count', fill_value = 0,
                 margins = True)

# %% [markdown]
# ### Упражнение
# Какой пользователь выставил больше всех пятерок?

# %% [markdown]
# # Объединение датафреймов
# Какой жанр имеет самые высокие рейтинги?

# %%
genres = ['Drama', 'Action', 'Thriller']

# %%
import numpy as np

# %%
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratings.head()

# %%
movies = pd.read_csv('ml-latest-small/movies.csv')
movies.head()

# %%
joined = ratings.merge(movies, on='movieId', how='left')
joined.head()

# %%
# рекомендуемая проверка на возможные дубликаты

len(ratings) == len(joined)

# %% [markdown]
# ### Немного о подводных камнях

# %%
ratings = pd.read_csv('ratings_example.txt', sep = '\t')
ratings.head()

# %%
movies = pd.read_csv('movies_example.txt', sep = '\t')
movies.head()

# %%
# ¯\_(ツ)_/¯

ratings.merge(movies, how = 'left', on = 'movieId')

# %%
movies.drop_duplicates(subset = 'movieId', keep = 'first', inplace = True)
movies.head()

# %%
ratings.merge(movies, how = 'left', on = 'movieId')

# %% [markdown]
# ### Считаем рейтинг жанров

# %%
# еще раз список жанров

genres = ['Drama', 'Action', 'Thriller']

# %%
def genres_ratings(row):
    """Возвращает рейтинг, если он есть в списке жанров данного фильма"""
    
    return pd.Series([row['rating'] if genre in row['genres'] else np.NaN for genre in genres])

# %%
joined[genres] = joined.apply(genres_ratings, axis=1)
joined.head()

# %% [markdown]
# ### Упражнение
# Выведите средний рейтинг каждого жанра из списка genres

# %% [markdown]
# # Немного про визуализации

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('sales_data.csv', sep=';')
data

# %%
plt.plot(data['month'], data['2016'])
plt.plot(data['2017'])
plt.plot(data['2018'])

# %%
plt.plot(data['month'], data['2016'], marker='o')
plt.plot(data['2017'], linestyle='dashed')
plt.plot(data['2016'], linewidth=5)

plt.legend()

# %% [markdown]
# ### Seaborn
# http://seaborn.pydata.org/examples/

# %%
features = pd.read_csv('correlation.tsv', sep='\t')
features

# %%
# месяц сейчас не пригодится

features.drop('month', axis=1, inplace=True)
features.head()

# %%
features.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f, ax = plt.subplots(figsize=(9, 6))

sns.heatmap(features.corr())

# %%
# добавляем наглядности

f, ax = plt.subplots(figsize=(9, 6))

sns.heatmap(features.corr(), annot=True, fmt='.1f', ax=ax, cmap=sns.color_palette('coolwarm', 16))
