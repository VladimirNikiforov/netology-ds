# %%
import pandas as pd
import time

# %%
with open('onegin.txt') as f:
  phrases = [s.replace('\t\t','') for s in f.read().split('\n') if s.startswith('\t\t')]

# %%
phrases
# Out:
# ['He мысля гордый свет забавить,',
#  'Вниманье дружбы возлюбя,',
#  'Хотел бы я тебе представить',
#  'Залог достойнее тебя,',
#  'Достойнее души прекрасной,',
#  'Святой исполненной мечты,',
#  'Поэзии живой и ясной,',
#  'Высоких дум и простоты;',
#  'Но так и быть – рукой пристрастной',
#  'Прими собранье пёстрых глав,',
#  'Полусмешных, полупечальных,',
#  'Простонародных, идеальных,',
#  'Небрежный плод моих забав,',
#  'Бессонниц, лёгких вдохновений,',
#  'Незрелых и увядших лет,',
#  'Ума холодных наблюдений',
#  'И сердца горестных замет.',
#  '«Мой дядя самых честных правил,',
#  'Когда не в шутку занемог,',
#  'Он уважать себя заставил',
#  'И лучше выдумать не мог.',
#  'Его пример другим наука;',
#  'Но, боже мой, какая скука',
#  'С больным сидеть и день и ночь,',
#  'Не отходя ни шагу прочь!',
#  'Какое низкое коварство',
#  'Полуживого забавлять,',
#  'Ему подушки поправлять,',
#  'Печально подносить лекарство,',
#  'Вздыхать и думать про себя:',
#  'Когда же чёрт возьмёт тебя!»',
#  'Так думал молодой повеса,',
#  'Летя в пыли на почтовых,',
#  'Всевышней волею Зевеса',
#  'Наследник всех своих родных.',
#  'Друзья Людмилы и Руслана!',
#  'С героем моего романа',
#  'Без предисловий, сей же час',
#  'Позвольте познакомить вас:',
#  'Онегин, добрый мой приятель,',
#  'Родился на брегах Невы,',
#  'Где, может быть, родились вы',
#  'Или блистали, мой читатель;',
#  'Там некогда гулял и я:',
#  'Но вреден север для меня[1] (#litres_trial_promo).',
#  'Служив отлично-благородно,',
#  'Долгами жил его отец,',
#  'Давал три бала ежегодно',
#  'И промотался наконец.',
#  'Судьба Евгения хранила:',
#  'Сперва Madame за ним ходила,',
#  'Потом Monsieur её сменил.',
#  'Ребёнок был резов, но мил.',
#  'Monsieur l’Abbе, француз убогой,',
#  'Чтоб не измучилось дитя,',
#  'Учил его всему шутя,',
#  'Не докучал моралью строгой,',
#  'Слегка за шалости бранил',
#  'И в Летний сад гулять водил.',
#  'Когда же юности мятежной',
#  'Пришла Евгению пора,',
#  'Пора надежд и грусти нежной,',
#  'Monsieur прогнали со двора.',
#  'Вот мой Онегин на свободе;',
#  'Острижен по последней моде;',
#  'Как dandy[2] (#litres_trial_promo) лондонский одет\xa0—',
#  'И наконец увидел свет.',
#  'Он по-французски совершенно',
#  'Мог изъясняться и писал;',
#  'Легко мазурку танцевал',
#  'И кланялся непринуждённо;',
#  'Чего ж вам больше? Свет решил,',
#  'Что он умен и очень мил.',
#  'Мы все учились понемногу',
#  'Чему-нибудь и как-нибудь,',
#  'Так воспитаньем, слава богу,',
#  'У нас немудрено блеснуть.',
#  'Онегин был, по мненью многих',
#  '(Судей решительных и строгих),',
#  'Учёный малый, но педант,',
#  'Имел он счастливый талант',
#  'Без принужденья в разговоре',
#  'Коснуться до всего слегка,',
#  'С учёным видом знатока',
#  'Хранить молчанье в важном споре',
#  'И возбуждать улыбку дам',
#  'Огнём нежданных эпиграмм.',
#  'Латынь из моды вышла ныне:',
#  'Так, если правду вам сказать,',
#  'Он знал довольно по-латыни,',
#  'Чтоб эпиграфы разбирать,',
#  'Потолковать об Ювенале,',
#  'В конце письма поставить vale[2 - Будь здоров (лат.).],',
#  'Да помнил, хоть не без греха,',
#  'Из Энеиды два стиха.',
#  'Он рыться не имел охоты',
#  'В хронологической пыли',
#  'Бытописания земли;',
#  'Но дней минувших анекдоты',
#  'От Ромула до наших дней',
#  'Хранил он в памяти своей.',
#  'Высокой страсти не имея',
#  'Для звуков жизни не щадить,',
#  'Не мог он ямба от хорея,',
#  'Как мы ни бились, отличить.',
#  'Бранил Гомера, Феокрита;',
#  'Зато читал Адама Смита',
#  'И был глубокий эконом,',
#  'То есть умел судить о том,',
#  'Как государство богатеет,',
#  'И чем живёт, и почему',
#  'Не нужно золота ему,',
#  'Когда простой продукт имеет.',
#  'Отец понять его не мог',
#  'И земли отдавал в залог.',
#  'Всего, что знал ещё Евгений,',
#  'Пересказать мне недосуг;',
#  'Но в чём он истинный был гений,',
#  'Что знал он твёрже всех наук,',
#  'Что было для него измлада',
#  'И труд, и мука, и отрада,',
#  'Что занимало целый день',
#  'Его тоскующую лень, —',
#  'Была наука страсти нежной,',
#  'Которую воспел Назон,',
#  'За что страдальцем кончил он',
#  'Свой век блестящий и мятежный',
#  'В Молдавии, в глуши степей,',
#  'Вдали Италии своей.',
#  '…………………………………',
#  '…………………………………',
#  '…………………………………',
#  'Как рано мог он лицемерить,',
#  'Таить надежду, ревновать,',
#  'Разуверять, заставить верить,',
#  'Казаться мрачным, изнывать,',
#  'Являться гордым и послушным,',
#  'Внимательным иль равнодушным!',
#  'Как томно был он молчалив,',
#  'Как пламенно красноречив,',
#  'В сердечных письмах как небрежен!',
#  'Одним дыша, одно любя,',
#  'Как он умел забыть себя!',
#  'Как взор его был быстр и нежен,',
#  'Стыдлив и дерзок, а порой',
#  'Блистал послушною слезой!',
#  'Как он умел казаться новым,',
#  'Шутя невинность изумлять,',
#  'Пугать отчаяньем готовым,',
#  'Приятной лестью забавлять,',
#  'Ловить минуту умиленья,',
#  'Невинных лет предубежденья',
#  'Умом и страстью побеждать,',
#  'Невольной ласки ожидать,',
#  'Молить и требовать признанья,',
#  'Подслушать сердца первый звук,',
#  'Преследовать любовь и вдруг',
#  'Добиться тайного свиданья…',
#  'И после ей наедине',
#  'Давать уроки в тишине!',
#  'Как рано мог уж он тревожить',
#  'Сердца кокеток записных!',
#  'Когда ж хотелось уничтожить',
#  'Ему соперников своих,',
#  'Как он язвительно злословил!',
#  'Какие сети им готовил!',
#  'Но вы, блаженные мужья,',
#  'С ним оставались вы друзья:',
#  'Его ласкал супруг лукавый,',
#  'Фобласа давний ученик,',
#  'И недоверчивый старик,',
#  'И рогоносец величавый,',
#  'Всегда довольный сам собой,',
#  'Своим обедом и женой.',
#  '……………………………………',
#  '……………………………………',
#  '……………………………………',
#  '……………………………………',
#  'Бывало, он ещё в постеле:',
#  'К нему записочки несут.',
#  'Что? Приглашенья? В самом деле,',
#  'Три дома на вечер зовут:',
#  'Там будет бал, там детский праздник.',
#  'Куда ж поскачет мой проказник?',
#  'С кого начнёт он? Всё равно:',
#  'Везде поспеть немудрено.',
#  'Покамест в утреннем уборе,',
#  'Надев широкий боливар[3] (#litres_trial_promo),',
#  'Онегин едет на бульвар',
#  'И там гуляет на просторе,',
#  'Пока недремлющий брегет',
#  'Не прозвонит ему обед.',
#  'Уж тёмно: в\xa0санки он садится.',
#  '«Пади, пади!»\xa0– раздался крик;',
#  'Морозной пылью серебрится',
#  'Его бобровый воротник.',
#  'К Talon[4] (#litres_trial_promo) помчался: он уверен,',
#  'Что там уж ждёт его Каверин.',
#  'Вошёл: и\xa0пробка в потолок,',
#  'Вина кометы брызнул ток,',
#  'Пред ним roast-beef окровавленный,',
#  'И трюфли, роскошь юных лет,',
#  'Французской кухни лучший цвет,',
#  'И Стразбурга пирог нетленный',
#  'Меж сыром лимбургским живым',
#  'И ананасом золотым.',
#  'Ещё бокалов жажда просит',
#  'Залить горячий жир котлет,',
#  'Но звон брегета им доносит,',
#  'Что новый начался балет.',
#  'Театра злой законодатель,',
#  'Непостоянный обожатель',
#  'Очаровательных актрис,',
#  'Почётный гражданин кулис,',
#  'Онегин полетел к театру,',
#  'Где каждый, вольностью дыша,',
#  'Готов охлопать entrechat,',
#  'Обшикать Федру, Клеопатру,',
#  'Моину вызвать (для того,',
#  'Чтоб только слышали его).',
#  'Волшебный край! там в стары годы,',
#  'Сатиры смелый властелин,',
#  'Блистал Фонвизин, друг свободы,',
#  'И переимчивый Княжнин;',
#  'Там Озеров невольны дани',
#  'Народных слез, рукоплесканий',
#  'С младой Семёновой делил;',
#  'Там наш Катенин воскресил',
#  'Корнеля гений величавый;',
#  'Там вывел колкий Шаховской',
#  'Своих комедий шумный рой,',
#  'Там и Дидло венчался славой,',
#  'Там, там под сению кулис',
#  'Младые дни мои неслись.',
#  'Мои богини! что вы? где вы?',
#  'Внемлите мой печальный глас:',
#  'Всё те же ль вы? другие ль девы,',
#  'Сменив, не заменили вас?',
#  'Услышу ль вновь я ваши хоры?',
#  'Узрю ли русской Терпсихоры',
#  'Душой исполненный полёт?',
#  'Иль взор унылый не найдёт',
#  'Знакомых лиц на сцене скучной,',
#  'И, устремив на чуждый свет',
#  'Разочарованный лорнет,',
#  'Веселья зритель равнодушный,',
#  'Безмолвно буду я зевать',
#  'И о былом воспоминать?',
#  'Театр уж полон; ложи блещут;',
#  'Партер и кресла, всё кипит;',
#  'В райке нетерпеливо плещут,',
#  'И, взвившись, занавес шумит.',
#  'Блистательна, полувоздушна,',
#  'Смычку волшебному послушна,',
#  'Толпою нимф окружена,',
#  'Стоит Истомина; она,',
#  'Одной ногой касаясь пола,',
#  'Другою медленно кружит,',
#  'И вдруг прыжок, и вдруг летит,',
#  'Летит, как пух от уст Эола;',
#  'То стан совьёт, то разовьёт,',
#  'И быстрой ножкой ножку бьёт.',
#  'Всё хлопает. Онегин входит,',
#  'Идёт меж кресел по ногам,',
#  'Двойной лорнет скосясь наводит',
#  'На ложи незнакомых дам;',
#  'Все ярусы окинул взором,',
#  'Всё видел: лицами, убором',
#  'Ужасно недоволен он;',
#  'С мужчинами со всех сторон',
#  'Раскланялся, потом на сцену',
#  'В большом рассеянье взглянул,',
#  'Отворотился – и зевнул,',
#  'И молвил: «Всех пора на смену;',
#  'Балеты долго я терпел,',
#  'Но и Дидло мне надоел»[5] (#litres_trial_promo).',
#  'Ещё амуры, черти, змеи',
#  'На сцене скачут и шумят;',
#  'Ещё усталые лакеи',
#  'На шубах у подъезда спят;',
#  'Ещё не перестали топать,',
#  'Сморкаться, кашлять, шикать, хлопать;',
#  'Ещё снаружи и внутри',
#  'Везде блистают фонари;',
#  'Ещё, прозябнув, бьются кони,',
#  'Наскуча упряжью своей,',
#  'И кучера, вокруг огней,',
#  'Бранят господ и бьют в ладони:',
#  'А уж Онегин вышел вон;',
#  'Домой одеться едет он.',
#  'Изображу ль в картине верной',
#  'Уединённый кабинет,',
#  'Где мод воспитанник примерный',
#  'Одет, раздет и вновь одет?',
#  'Всё, чем для прихоти обильной',
#  'Торгует Лондон щепетильный',
#  'И по Балтическим волнам',
#  'За лес и сало возит нам,',
#  'Всё, что в Париже вкус голодный,',
#  'Полезный промысел избрав,',
#  'Изобретает для забав,',
#  'Для роскоши, для неги модной, —',
#  'Всё украшало кабинет',
#  'Философа в осьмнадцать лет.',
#  'Янтарь на трубках Цареграда,',
#  'Фарфор и бронза на столе,',
#  'И, чувств изнеженных отрада,',
#  'Духи в гранёном хрустале;',
#  'Гребёнки, пилочки стальные,',
#  'Прямые ножницы, кривые,',
#  'И щётки тридцати родов',
#  'И для ногтей и для зубов.',
#  'Руссо (замечу мимоходом)',
#  'Не мог понять, как важный Грим',
#  'Смел чистить ногти перед ним,',
#  'Красноречивым сумасбродом[6] (#litres_trial_promo).',
#  'Защитник вольности и прав',
#  'В сём случае совсем неправ.',
#  'Быть можно дельным человеком',
#  'И думать о красе ногтей:',
#  'К чему бесплодно спорить с веком?',
#  'Обычай деспот меж людей.',
#  'Второй Чадаев, мой Евгений,',
#  'Боясь ревнивых осуждений,',
#  'В своей одежде был педант',
#  'И то, что мы назвали франт.',
#  'Он три часа по крайней мере',
#  'Пред зеркалами проводил',
#  'И из уборной выходил',
#  'Подобный ветреной Венере,',
#  'Когда, надев мужской наряд,',
#  'Богиня едет в маскарад.',
#  'В последнем вкусе туалетом',
#  'Заняв ваш любопытный взгляд,',
#  'Я мог бы пред учёным светом',
#  'Здесь описать его наряд;',
#  'Конечно б это было смело,',
#  'Описывать моё же дело:',
#  'Но панталоны, фрак, жилет,',
#  'Всех этих слов на русском нет;',
#  'А вижу я, винюсь пред вами,',
#  'Что уж и так мой бедный слог',
#  'Пестреть гораздо б меньше мог',
#  'Иноплеменными словами,',
#  'Хоть и заглядывал я встарь',
#  'В Академический Словарь.',
#  'У нас теперь не то в предмете:',
#  'Мы лучше поспешим на бал,',
#  'Куда стремглав в ямской карете',
#  'Уж мой Онегин поскакал.',
#  'Перед померкшими домами',
#  'Вдоль сонной улицы рядами',
#  'Двойные фонари карет',
#  'Весёлый изливают свет',
#  'И радуги на снег наводят;',
#  'Усеян плошками кругом,',
#  'Блестит великолепный дом;',
#  'По цельным окнам тени ходят,',
#  'Мелькают профили голов',
#  'И дам и модных чудаков.',
#  'Вот наш герой подъехал к сеням;',
#  'Швейцара мимо он стрелой',
#  'Взлетел по мраморным ступеням,',
#  'Расправил волоса рукой,',
#  'Вошёл. Полна народу зала;',
#  'Музыка уж греметь устала;',
#  'Толпа мазуркой занята;',
#  'Кругом и шум и теснота;',
#  'Бренчат кавалергарда шпоры;',
#  'Летают ножки милых дам;',
#  'По их пленительным следам',
#  'Летают пламенные взоры,',
#  'И рёвом скрыпок заглушён',
#  'Ревнивый шёпот модных жён.',
#  'Во дни веселий и желаний',
#  'Я был от балов без ума:',
#  'Верней нет места для признаний',
#  'И для вручения письма.',
#  'О вы, почтенные супруги!',
#  'Вам предложу свои услуги;',
#  'Прошу мою заметить речь:',
#  'Я вас хочу предостеречь.',
#  'Вы также, маменьки, построже',
#  'За дочерьми смотрите вслед:',
#  'Держите прямо свой лорнет!',
#  'Не то… не то, избави боже!',
#  'Я это потому пишу,',
#  'Что уж давно я не грешу.',
#  'Увы, на разные забавы',
#  'Я много жизни погубил!',
#  'Но если б не страдали нравы,',
#  'Я балы б до сих пор любил.',
#  'Люблю я бешеную младость,',
#  'И тесноту, и блеск, и радость,',
#  'И дам обдуманный наряд;',
#  'Люблю их ножки; только вряд',
#  'Найдёте вы в России целой',
#  'Три пары стройных женских ног.',
#  'Ах! долго я забыть не мог',
#  'Две ножки… Грустный, охладелый,',
#  'Я всё их помню, и во сне',
#  'Они тревожат сердце мне.',
#  'Когда ж и где, в какой пустыне,',
#  'Безумец, их забудешь ты?',
#  'Ах, ножки, ножки! где вы ныне?',
#  'Где мнёте вешние цветы?',
#  'Взлелеяны в восточной неге,',
#  'На северном, печальном снеге',
#  'Вы не оставили следов:',
#  'Любили мягких вы ковров',
#  'Роскошное прикосновенье.',
#  'Давно ль для вас я забывал',
#  'И жажду славы и похвал,',
#  'И край отцов, и заточенье?',
#  'Исчезло счастье юных лет\xa0—',
#  'Как на лугах ваш лёгкий след.',
#  'Дианы грудь, ланиты Флоры',
#  'Прелестны, милые друзья!',
#  'Однако ножка Терпсихоры',
#  'Прелестней чем-то для меня.',
#  'Она, пророчествуя взгляду',
#  'Неоценимую награду,',
#  'Влечёт условною красой',
#  'Желаний своевольный рой.',
#  'Люблю её, мой друг Эльвина,',
#  'Под длинной скатертью столов,',
#  'Весной на мураве лугов,',
#  'Зимой на чугуне камина,',
#  'На зе?ркальном паркете зал,',
#  'У моря на граните скал.',
#  'Я помню море пред грозою:',
#  'Как я завидовал волнам,',
#  'Бегущим бурной чередою',
#  'С любовью лечь к её ногам!',
#  'Как я желал тогда с волнами',
#  'Коснуться милых ног устами!',
#  'Нет, никогда средь пылких дней',
#  'Кипящей младости моей',
#  'Я не желал с таким мученьем',
#  'Лобзать уста младых Армид,',
#  'Иль розы пламенных ланит,',
#  'Иль перси, полные томленьем;',
#  'Нет, никогда порыв страстей',
#  'Так не терзал души моей!',
#  'Мне памятно другое время!',
#  'В заветных иногда мечтах',
#  'Держу я счастливое стремя…',
#  'И ножку чувствую в руках;',
#  'Опять кипит воображенье,',
#  'Опять её прикосновенье',
#  'Зажгло в увядшем сердце кровь,',
#  'Опять тоска, опять любовь!..',
#  'Но полно прославлять надменных',
#  'Болтливой лирою своей;',
#  'Они не стоят ни страстей,',
#  'Ни песен, ими вдохновенных:',
#  'Слова и взор волшебниц сих',
#  'Обманчивы… как ножки их.',
#  'Что ж мой Онегин? Полусонный',
#  'В постелю с бала едет он:',
#  'А Петербург неугомонный',
#  'Уж барабаном пробуждён.',
#  'Встаёт купец, идёт разносчик,',
#  'На биржу тянется извозчик,',
#  'С кувшином охтинка спешит,',
#  'Под ней снег утренний хрустит.',
#  'Проснулся утра шум приятный.',
#  'Открыты ставни; трубный дым',
#  'Столбом восходит голубым,',
#  'И хлебник, немец аккуратный,',
#  'В бумажном колпаке, не раз',
#  'Уж отворял свой васисдас.',
#  'Но, шумом бала утомлённый',
#  'И утро в полночь обратя,',
#  'Спокойно спит в тени блаженной',
#  'Забав и роскоши дитя.',
#  'Проснётся за? полдень, и снова',
#  'До утра жизнь его готова,',
#  'Однообразна и пестра.',
#  'И завтра то же, что вчера.',
#  'Но был ли счастлив мой Евгений,',
#  'Свободный, в цвете лучших лет,',
#  'Среди блистательных побед,',
#  'Среди вседневных наслаждений?',
#  'Вотще ли был он средь пиров',
#  'Неосторожен и здоров?',
#  'Нет: рано чувства в нём остыли;',
#  'Ему наскучил света шум;',
#  'Красавицы не долго были',
#  'Предмет его привычных дум;',
#  'Измены утомить успели;',
#  'Друзья и дружба надоели,',
#  'Затем, что не всегда же мог',
#  'Beef-steaks и страсбургский пирог',
#  'Шампанской обливать бутылкой',
#  'И сыпать острые слова,',
#  'Когда болела голова;',
#  'И хоть он был повеса пылкой,',
#  'Но разлюбил он наконец',
#  'И брань, и саблю, и свинец.',
#  'Недуг, которого причину',
#  'Давно бы отыскать пора,',
#  'Подобный английскому сплину,',
#  'Короче: русская хандра',
#  'Им овладела понемногу;',
#  'Он застрелиться, слава богу,',
#  'Попробовать не захотел,',
#  'Но к жизни вовсе охладел.',
#  'Как Child-Harold, угрюмый, томный',
#  'В гостиных появлялся он;',
#  'Ни сплетни света, ни бостон,',
#  'Ни милый взгляд, ни вздох',
#  'нескромный,',
#  'Ничто не трогало его,',
#  'Не замечал он ничего.',
#  '……………………………………',
#  '……………………………………',
#  '……………………………………',
#  'Причудницы большого света!',
#  'Всех прежде вас оставил он;',
#  'И правда то, что в наши лета',
#  'Довольно скучен высший тон;',
#  'Хоть, может быть, иная дама',
#  'Толкует Сея и Бентама,',
#  'Но вообще их разговор',
#  'Несносный, хоть невинный вздор;',
#  'К тому ж они так непорочны,',
#  'Так величавы, так умны,',
#  'Так благочестия полны,',
#  'Так осмотрительны, так точны,',
#  'Так неприступны для мужчин,',
#  'Что вид их уж рождает сплин[7] (#litres_trial_promo).',
#  'И вы, красотки молодые,',
#  'Которых позднею порой',
#  'Уносят дрожки удалые',
#  'По петербургской мостовой,',
#  'И вас покинул мой Евгений.',
#  'Отступник бурных наслаждений,',
#  'Онегин дома заперся,',
#  'Зевая, за перо взялся,',
#  'Хотел писать – но труд упорный',
#  'Ему был тошен; ничего',
#  'Не вышло из пера его,',
#  'И не попал он в цех задорный',
#  'Людей, о коих не сужу,',
#  'Затем, что к ним принадлежу.',
#  'И снова, преданный безделью,',
#  'Томясь душевной пустотой,',
#  'Уселся он – с похвальной целью',
#  'Себе присвоить ум чужой;',
#  'Отрядом книг уставил полку,',
#  'Читал, читал, а всё без толку:',
#  'Там скука, там обман иль бред;',
#  'В том совести, в том смысла нет;',
#  'На всех различные вериги;',
#  'И устарела старина,',
#  'И старым бредит новизна.',
#  'Как женщин, он оставил книги,',
#  'И полку, с пыльной их семьёй,',
#  'Задёрнул траурной тафтой.',
#  'Условий света свергнув бремя,',
#  'Как он, отстав от суеты,',
#  'С ним подружился я в то время.',
#  'Мне нравились его черты,',
#  'Мечтам невольная преданность,',
#  'Неподражательная странность',
#  'И резкий, охлаждённый ум.',
#  'Я был озлоблен, он угрюм;',
#  'Страстей игру мы знали оба:',
#  'Томила жизнь обоих нас;',
#  'В обоих сердца жар угас;',
#  'Обоих ожидала злоба',
#  'Слепой Фортуны и людей',
#  'На самом утре наших дней.',
#  'Кто жил и мыслил, тот не может',
#  'В душе не презирать людей;',
#  'Кто чувствовал, того тревожит',
#  'Призра?к невозвратимых дней:',
#  'Тому уж нет очарований.',
#  'Того змия воспоминаний,',
#  'Того раскаянье грызёт.',
#  'Всё это часто придаёт',
#  'Большую прелесть разговору.',
#  'Сперва Онегина язык',
#  'Меня смущал; но я привык',
#  'К его язвительному спору,',
#  'И к шутке с желчью пополам,',
#  'И злости мрачных эпиграмм.',
#  'Как часто летнею порою,',
#  'Когда прозрачно и светло',
#  'Ночное небо над Невою[8] (#litres_trial_promo)',
#  'И вод весёлое стекло',
#  'Не отражает лик Дианы,',
#  'Воспомня прежних лет романы,',
#  'Воспомня прежнюю любовь,',
#  'Чувствительны, беспечны вновь,',
#  'Дыханьем ночи благосклонной',
#  'Безмолвно упивались мы!',
#  'Как в лес зелёный из тюрьмы',
#  'Перенесён колодник сонный,',
#  'Так уносились мы мечтой',
#  'К началу жизни молодой.',
#  'С душою, полной сожалений,',
#  'И опершися на гранит,',
#  'Стоял задумчиво Евгений,',
#  'Как описал себя пиит [9] (#litres_trial_promo).',
#  'Всё было тихо; лишь ночные',
#  'Перекликались часовые,',
#  'Да дрожек отдалённый стук',
#  'С Мильонной раздавался вдруг;',
#  'Лишь лодка, вёслами махая,',
#  'Плыла по дремлющей реке:',
#  'И нас пленяли вдалеке',
#  'Рожок и песня удалая…',
#  'Но слаще, средь ночных забав,',
#  'Напев Торкватовых октав!',
#  'Адриатические волны,',
#  'О Брента! нет, увижу вас',
#  'И, вдохновенья снова полный,',
#  'Услышу ваш волшебный глас!',
#  'Он свят для внуков Аполлона;',
#  'По гордой лире Альбиона',
#  'Он мне знаком, он мне родной.',
#  'Ночей Италии златой',
#  'Я негой наслажусь на воле,',
#  'С венецианкою младой,',
#  'То говорливой, то немой,',
#  'Плывя в таинственной гондоле;',
#  'С ней обретут уста мои',
#  'Язык Петрарки и любви.',
#  'Придёт ли час моей свободы?',
#  'Пора, пора!\xa0– взываю к ней;',
#  'Брожу над морем[10] (#litres_trial_promo), жду погоды,',
#  'Маню ветрила кораблей.',
#  'Под ризой бурь, с волнами споря,',
#  'По вольному распутью моря',
#  'Когда ж начну я вольный бег?',
#  'Пора покинуть скучный брег',
#  'Мне неприязненной стихии,',
#  'И средь полуденных зыбей,',
#  'Под небом Африки моей[11] (#litres_trial_promo),',
#  'Вздыхать о сумрачной России,',
#  'Где я страдал, где я любил,',
#  'Где сердце я похоронил.',
#  'Онегин был готов со мною',
#  'Увидеть чуждые страны;',
#  'Но скоро были мы судьбою',
#  'На долгий срок разведены.',
#  'Отец его тогда скончался.',
#  'Перед Онегиным собрался',
#  'Заимодавцев жадный полк.',
#  'У каждого свой ум и толк:',
#  'Евгений, тяжбы ненавидя,',
#  'Довольный жребием своим,',
#  'Наследство предоставил им,',
#  'Большой потери в том не видя',
#  'Иль предузнав издалека',
#  'Кончину дяди-старика.',
#  'Вдруг получил он в самом деле',
#  'От управителя доклад,',
#  'Что дядя при смерти в постеле',
#  'И с ним проститься был бы рад.',
#  'Прочтя печальное посланье,',
#  'Евгений тотчас на свиданье',
#  'Стремглав по почте поскакал',
#  'И уж заранее зевал,',
#  'Приготовляясь, денег ради,',
#  'На вздохи, скуку и обман',
#  '(И тем я начал мой роман);',
#  'Но, прилетев в деревню дяди,',
#  'Его нашёл уж на столе,',
#  'Как дань готовую земле.',
#  'Нашёл он полон двор услуги;',
#  'К покойнику со всех сторон',
#  'Съезжались недруги и други,',
#  'Охотники до похорон.',
#  'Покойника похоронили.',
#  'Попы и гости ели, пили',
#  'И после важно разошлись,',
#  'Как будто делом занялись.',
#  'Вот наш Онегин сельский житель,',
#  'Заводов, вод, лесов, земель',
#  'Хозяин полный, а досель',
#  'Порядка враг и расточитель,',
#  'И очень рад, что прежний путь',
#  'Переменил на что-нибудь.',
#  'Два дня ему казались новы',
#  'Уединённые поля,',
#  'Прохлада сумрачной дубровы,',
#  'Журчанье тихого ручья;',
#  'На третий роща, холм и поле',
#  'Его не занимали боле;',
#  'Потом уж наводили сон;',
#  'Потом увидел ясно он,',
#  'Что и в деревне скука та же,',
#  'Хоть нет ни улиц, ни дворцов,',
#  'Ни карт, ни балов, ни стихов.',
#  'Хандра ждала его на страже,',
#  'И бегала за ним она,',
#  'Как тень иль верная жена.',
#  'Я был рождён для жизни мирной,',
#  'Для деревенской тишины:',
#  'В глуши звучнее голос лирный,',
#  'Живее творческие сны.',
#  'Досугам посвятясь невинным,',
#  'Брожу над озером пустынным,',
#  'И far niente[3 - Безделье, праздность (итал.).] мой закон.',
#  'Я каждым утром пробуждён',
#  'Для сладкой неги и свободы:',
#  'Читаю мало, долго сплю,',
#  'Летучей славы не ловлю.',
#  'Не так ли я в былые годы',
#  'Провёл в бездействии, в тени',
#  'Мои счастливейшие дни?',
#  'Цветы, любовь, деревня, праздность,',
#  'Поля! я\xa0предан вам душой.',
#  'Всегда я рад заметить разность',
#  'Между Онегиным и мной,',
#  'Чтобы насмешливый читатель',
#  'Или какой-нибудь издатель',
#  'Замысловатой клеветы,',
#  'Сличая здесь мои черты,',
#  'Не повторял потом безбожно,',
#  'Что намарал я свой портрет,',
#  'Как Байрон, гордости поэт,',
#  'Как будто нам уж невозможно',
#  'Писать поэмы о другом,',
#  'Как только о себе самом.',
#  'Замечу кстати: все поэты\xa0—',
#  'Любви мечтательной друзья.',
#  'Бывало, милые предметы',
#  'Мне снились, и душа моя',
#  'Их образ тайный сохранила;',
#  'Их после муза оживила:',
#  'Так я, беспечен, воспевал',
#  'И деву гор, мой идеал,',
#  'И пленниц берегов Салгира.',
#  'Теперь от вас, мои друзья,',
#  'Вопрос нередко слышу я:',
#  '«О ком твоя вздыхает лира?',
#  'Кому, в толпе ревнивых дев,',
#  'Ты посвятил её напев?',
#  'Чей взор, волнуя вдохновенье,',
#  'Умильной лаской наградил',
#  'Твоё задумчивое пенье?',
#  'Кого твой стих боготворил?»',
#  'И, други, никого, ей-богу!',
#  'Любви безумную тревогу',
#  'Я безотрадно испытал.',
#  'Блажен, кто с нею сочетал',
#  'Горячку рифм: он тем удвоил',
#  'Поэзии священный бред,',
#  'Петрарке шествуя вослед,',
#  'А муки сердца успокоил,',
#  'Поймал и славу между тем;',
#  'Но я, любя, был глуп и нем.',
#  'Прошла любовь, явилась муза,',
#  'И прояснился тёмный ум.',
#  'Свободен, вновь ищу союза',
#  'Волшебных звуков, чувств и дум;',
#  'Пишу, и сердце не тоскует,',
#  'Перо, забывшись, не рисует,',
#  'Близ неоконченных стихов,',
#  'Ни женских ножек, ни голов;',
#  'Погасший пепел уж не вспыхнет,',
#  'Я всё грущу; но слёз уж нет,',
#  'И скоро, скоро бури след',
#  'В душе моей совсем утихнет:',
#  'Тогда-то я начну писать',
#  'Поэму песен в двадцать пять.',
#  'Я думал уж о форме плана,',
#  'И как героя назову;',
#  'Покамест моего романа',
#  'Я кончил первую главу;',
#  'Пересмотрел всё это строго:',
#  'Противоречий очень много,',
#  'Но их исправить не хочу.',
#  'Цензуре долг свой заплачу,',
#  'И журналистам на съеденье',
#  'Плоды трудов моих отдам:',
#  'Иди же к невским берегам,',
#  'Новорождённое творенье,',
#  'И заслужи мне славы дань:',
#  'Кривые толки, шум и брань!',
#  'Деревня, где скучал Евгений,',
#  'Была прелестный уголок;',
#  'Там друг невинных наслаждений',
#  'Благословить бы небо мог.',
#  'Господский дом уединённый,',
#  'Горой от ветров ограждённый,',
#  'Стоял над речкою. Вдали',
#  'Пред ним пестрели и цвели',
#  'Луга и нивы золотые,',
#  'Мелькали сёла; здесь и там',
#  'Стада бродили по лугам,',
#  'И сени расширял густые',
#  'Огромный, запущённый сад,',
#  'Приют задумчивых Дриад.',
#  'Почтенный за?мок был построен,',
#  'Как замки строиться должны:',
#  'Отменно прочен и спокоен',
#  'Во вкусе умной старины.',
#  'Везде высокие покои,',
#  'В гостиной штофные обои,',
#  'Царей портреты на стенах,',
#  'И печи в пёстрых изразцах.',
#  'Всё это ныне обветшало,',
#  'Не знаю, право, почему;',
#  'Да, впрочем, другу моему',
#  'В том нужды было очень мало,',
#  'Затем что он равно зевал',
#  'Средь модных и старинных зал.',
#  'Он в том покое поселился,',
#  'Где деревенский старожил',
#  'Лет сорок с ключницей бранился,',
#  'В окно смотрел и мух давил.',
#  'Всё было просто: пол дубовый,',
#  'Два шкафа, стол, диван пуховый,',
#  'Нигде ни пятнышка чернил.',
#  'Онегин шкафы отворил:',
#  'В одном нашёл тетрадь расхода,',
#  'В другом наливок целый строй,',
#  'Кувшины с яблочной водой',
#  'И календарь осьмого года:',
#  'Старик, имея много дел,',
#  'В иные книги не глядел.',
#  'Один среди своих владений,',
#  'Чтоб только время проводить,',
#  'Сперва задумал наш Евгений',
#  'Порядок новый учредить.',
#  'В своей глуши мудрец пустынный,',
#  'Ярем он барщины старинной',
#  'Оброком лёгким заменил;',
#  'И раб судьбу благословил.',
#  'Зато в углу своём надулся,',
#  'Увидя в этом страшный вред,',
#  'Его расчётливый сосед.',
#  'Другой лукаво улыбнулся,',
#  'И в голос все решили так,',
#  'Что он опаснейший чудак.',
#  'Сначала все к нему езжали;',
#  'Но так как с заднего крыльца',
#  'Обыкновенно подавали',
#  'Ему донского жеребца,',
#  'Лишь только вдоль большой дороги',
#  'Заслышит их домашни дроги, —',
#  'Поступком оскорбясь таким,',
#  'Все дружбу прекратили с ним.',
#  '«Сосед наш неуч, сумасбродит,',
#  'Он фармазон; он пьёт одно',
#  'Стаканом красное вино;',
#  'Он дамам к ручке не подходит;',
#  'Всё да да нет; не скажет да-с',
#  'Иль нет-с». Таков был общий глас.',
#  'В свою деревню в ту же пору',
#  'Помещик новый прискакал',
#  'И столь же строгому разбору',
#  'В соседстве повод подавал.',
#  'По имени Владимир Ленский,',
#  'С душою прямо геттингенской,',
#  'Красавец, в полном цвете лет,',
#  'Поклонник Канта и поэт.',
#  'Он из Германии туманной',
#  'Привёз учёности плоды:',
#  'Вольнолюбивые мечты,',
#  'Дух пылкий и довольно странный,',
#  'Всегда восторженную речь',
#  'И кудри чёрные до плеч.',
#  'От хладного разврата света',
#  'Ещё увянуть не успев,',
#  'Его душа была согрета',
#  'Приветом друга, лаской дев.',
#  'Он сердцем милый был невежда,',
#  'Его лелеяла надежда,',
#  'И мира новый блеск и шум',
#  'Ещё пленяли юный ум.',
#  'Он забавлял мечтою сладкой',
#  'Сомненья сердца своего;',
#  'Цель жизни нашей для него',
#  'Была заманчивой загадкой,',
#  'Над ней он голову ломал',
#  'И чудеса подозревал.',
#  'Он верил, что душа родная',
#  'Соединиться с ним должна,',
#  'Что, безотрадно изнывая,',
#  'Его вседневно ждёт она;',
#  'Он верил, что друзья готовы',
#  'За честь его приять оковы,',
#  'И что не дрогнет их рука',
#  'Разбить сосуд клеветника;',
#  'Что есть избранные судьбами,',
#  'Людей священные друзья;',
#  'Что их бессмертная семья',
#  'Неотразимыми лучами',
#  'Когда-нибудь нас озарит',
#  'И мир блаженством одарит.',
#  'Негодованье, сожаленье,',
#  'Ко благу чистая любовь',
#  'И славы сладкое мученье',
#  'В нём рано волновали кровь.',
#  'Он с лирой странствовал на свете;',
#  'Под небом Шиллера и Гёте',
#  'Их поэтическим огнём',
#  'Душа воспламенилась в нём.',
#  'И муз возвышенных искусства,',
#  'Счастливец, он не постыдил;',
#  'Он в песнях гордо сохранил',
#  'Всегда возвышенные чувства,',
#  'Порывы девственной мечты',
#  'И прелесть важной простоты.',
#  'Он пел любовь, любви послушный,',
#  'И песнь его была ясна,',
#  'Как мысли девы простодушной,',
#  'Как сон младенца, как луна',
#  'В пустынях неба безмятежных,',
#  'Богиня тайн и вздохов нежных.',
#  'Он пел разлуку и печаль,',
#  'И нечто, и туманну даль,',
#  'И романтические розы;',
#  'Он пел те дальные страны,',
#  'Где долго в лоно тишины',
#  'Лились его живые слёзы;',
#  'Он пел поблеклый жизни цвет',
#  'Без малого в осьмнадцать лет.',
#  'В пустыне, где один Евгений',
#  'Мог оценить его дары,',
#  'Господ соседственных селений',
#  'Ему не нравились пиры;',
#  'Бежал он их беседы шумной.',
#  'Их разговор благоразумный',
#  'О сенокосе, о вине,',
#  'О псарне, о своей родне,',
#  'Конечно, не блистал ни чувством,',
#  'Ни поэтическим огнём,',
#  'Ни остротою, ни умом,',
#  'Ни общежития искусством;',
#  'Но разговор их милых жён',
#  'Гораздо меньше был умён.',
#  'Богат, хорош собою, Ленский',
#  'Везде был принят как жених;',
#  'Таков обычай деревенский;',
#  'Все дочек прочили своих',
#  'За полурусского соседа;',
#  'Взойдёт ли он, тотчас беседа',
#  'Заводит слово стороной',
#  'О скуке жизни холостой;',
#  'Зовут соседа к самовару,',
#  'А Дуня разливает чай,',
#  'Ей шепчут: «Дуня, примечай!»',
#  'Потом приносят и гитару:',
#  'И запищит она (Бог мой!):',
#  'Приди в чертог ко мне златой!..[12] (#litres_trial_promo)',
#  'Но Ленский, не имев, конечно,',
#  'Охоты узы брака несть,',
#  'С Онегиным желал сердечно',
#  'Знакомство покороче свесть.',
#  'Они сошлись. Волна и камень,',
#  'Стихи и проза, лёд и пламень',
#  'Не столь различны меж собой.',
#  'Сперва взаимной разнотой',
#  'Они друг другу были скучны;',
#  'Потом понравились; потом',
#  'Съезжались каждый день верхом',
#  'И скоро стали неразлучны.',
#  'Так люди (первый каюсь я)',
#  'От делать нечего друзья.',
#  'Но дружбы нет и той меж нами.',
#  'Все предрассудки истребя,',
#  'Мы почитаем всех нулями,',
#  'А единицами – себя.',
#  'Мы все глядим в Наполеоны;',
#  'Двуногих тварей миллионы',
#  'Для нас орудие одно;',
#  'Нам чувство дико и смешно.',
#  'Сноснее многих был Евгений;',
#  'Хоть он людей, конечно, знал',
#  'И вообще их презирал, —',
#  'Но (правил нет без исключений)',
#  'Иных он очень отличал',
#  'И вчуже чувство уважал.',
#  'Он слушал Ленского с улыбкой.',
#  'Поэта пылкий разговор,',
#  'И ум, ещё в сужденьях зыбкий,',
#  'И вечно вдохновенный взор, —',
#  'Онегину всё было ново;',
#  'Он охладительное слово',
#  'В устах старался удержать',
#  'И думал: глупо мне мешать',
#  'Его минутному блаженству;',
#  'И без меня пора придёт;',
#  'Пускай покамест он живёт',
#  'Да верит мира совершенству;',
#  'Простим горячке юных лет',
#  'И юный жар и юный бред.',
#  'Меж ими всё рождало споры',
#  'И к размышлению влекло:',
#  'Племён минувших договоры,',
#  'Плоды наук, добро и зло,',
#  'И предрассудки вековые,',
#  'И гроба тайны роковые,',
#  ...]

# %%
phrases[:10]
# Out:
# ['He мысля гордый свет забавить,',
#  'Вниманье дружбы возлюбя,',
#  'Хотел бы я тебе представить',
#  'Залог достойнее тебя,',
#  'Достойнее души прекрасной,',
#  'Святой исполненной мечты,',
#  'Поэзии живой и ясной,',
#  'Высоких дум и простоты;',
#  'Но так и быть – рукой пристрастной',
#  'Прими собранье пёстрых глав,']

# %%
text = [[c for c in ph] for ph in phrases if type(ph) is str]

# %%
CHARS = set('абвгдеёжзийклмнопрстуфхцчшщъыьэюя ')

# %%
INDEX_TO_CHAR = ['none'] + [w for w in CHARS]

# %%
INDEX_TO_CHAR
# Out:
# ['none',
#  'е',
#  'ю',
#  'щ',
#  'д',
#  'л',
#  'р',
#  'б',
#  'ч',
#  'ё',
#  'а',
#  'ф',
#  'п',
#  'с',
#  'я',
#  'г',
#  'з',
#  'у',
#  'й',
#  'м',
#  'ц',
#  'и',
#  'о',
#  'в',
#  'н',
#  'ы',
#  'т',
#  'ъ',
#  'к',
#  'ш',
#  'х',
#  'ь',
#  'ж',
#  'э',
#  ' ']

# %%
CHAR_TO_INDEX = {w: i for i, w in enumerate(INDEX_TO_CHAR)}

# %%
CHAR_TO_INDEX
# Out:
# {'none': 0,
#  'е': 1,
#  'ю': 2,
#  'щ': 3,
#  'д': 4,
#  'л': 5,
#  'р': 6,
#  'б': 7,
#  'ч': 8,
#  'ё': 9,
#  'а': 10,
#  'ф': 11,
#  'п': 12,
#  'с': 13,
#  'я': 14,
#  'г': 15,
#  'з': 16,
#  'у': 17,
#  'й': 18,
#  'м': 19,
#  'ц': 20,
#  'и': 21,
#  'о': 22,
#  'в': 23,
#  'н': 24,
#  'ы': 25,
#  'т': 26,
#  'ъ': 27,
#  'к': 28,
#  'ш': 29,
#  'х': 30,
#  'ь': 31,
#  'ж': 32,
#  'э': 33,
#  ' ': 34}

# %%
import torch

# %%
MAX_LEN = 30

# %%
X = torch.zeros((len(text), MAX_LEN), dtype=int)

# %%
for i in range(len(text)):
    for j, w in enumerate(text[i]):
        if j >= MAX_LEN:
            break
        X[i, j] = CHAR_TO_INDEX.get(w, CHAR_TO_INDEX['none'])

# %%
X[0:1]
# Out:
# tensor([[ 0,  0, 34, 19, 25, 13,  5, 14, 34, 15, 22,  6,  4, 25, 18, 34, 13, 23,
#           1, 26, 34, 16, 10,  7, 10, 23, 21, 26, 31,  0]])

# %%
class Network(torch.nn.Module):

    def __init__(self):
        super(Network, self).__init__()
        self.word_embeddings = torch.nn.Embedding(len(INDEX_TO_CHAR), 35)
        self.gru = torch.nn.RNN(35, 128, batch_first=True)
        self.hidden2tag = torch.nn.Linear(128, len(INDEX_TO_CHAR))

    def forward(self, sentences):
        embeds = self.word_embeddings(sentences)
        gru_out, state = self.gru(embeds)
        tag_space = self.hidden2tag(gru_out.reshape(-1, 128))
        return tag_space.reshape(sentences.shape[0], sentences.shape[1], -1), state

    def forward_state(self, sentences, state):
        embeds = self.word_embeddings(sentences)
        gru_out, state = self.gru(embeds, state)
        tag_space = self.hidden2tag(gru_out.reshape(-1, 128))
        return tag_space.reshape(sentences.shape[0], sentences.shape[1], -1), state

# %%
class NetworkGRU(torch.nn.Module):

    def __init__(self):
        super(NetworkGRU, self).__init__()
        self.word_embeddings = torch.nn.Embedding(len(INDEX_TO_CHAR), 35)
        self.gru = torch.nn.GRU(35, 128, batch_first=True)
        self.hidden2tag = torch.nn.Linear(128, len(INDEX_TO_CHAR))

    def forward(self, sentences):
        embeds = self.word_embeddings(sentences)
        gru_out, state = self.gru(embeds)
        tag_space = self.hidden2tag(gru_out.reshape(-1, 128))
        return tag_space.reshape(sentences.shape[0], sentences.shape[1], -1), state

    def forward_state(self, sentences, state):
        embeds = self.word_embeddings(sentences)
        gru_out, state = self.gru(embeds, state)
        tag_space = self.hidden2tag(gru_out.reshape(-1, 128))
        return tag_space.reshape(sentences.shape[0], sentences.shape[1], -1), state

# %%
class NetworkLSTM(torch.nn.Module):

    def __init__(self):
        super(NetworkLSTM, self).__init__()
        self.word_embeddings = torch.nn.Embedding(len(INDEX_TO_CHAR), 35)
        self.lstm = torch.nn.LSTM(35, 128, batch_first=True)
        self.hidden2tag = torch.nn.Linear(128, len(INDEX_TO_CHAR))

    def forward(self, sentences):
        embeds = self.word_embeddings(sentences)
        gru_out, state = self.lstm(embeds)
        tag_space = self.hidden2tag(gru_out.reshape(-1, 128))
        return tag_space.reshape(sentences.shape[0], sentences.shape[1], -1), state

    def forward_state(self, sentences, state):
        embeds = self.word_embeddings(sentences)
        gru_out, state = self.lstm(embeds, state)
        tag_space = self.hidden2tag(gru_out.reshape(-1, 128))
        return tag_space.reshape(sentences.shape[0], sentences.shape[1], -1), state

# %%
class NetworkUber(torch.nn.Module):

    def __init__(self):
        super(NetworkUber, self).__init__()
        self.word_embeddings = torch.nn.Embedding(len(INDEX_TO_CHAR), 35)
        self.gru = torch.nn.GRU(35, 128, batch_first=True, num_layers=3)
        self.hidden2tag = torch.nn.Linear(128, len(INDEX_TO_CHAR))

    def forward(self, sentences):
        embeds = self.word_embeddings(sentences)
        gru_out, state = self.gru(embeds)
        tag_space = self.hidden2tag(gru_out.reshape(-1, 128))
        return tag_space.reshape(sentences.shape[0], sentences.shape[1], -1), state

    def forward_state(self, sentences, state):
        embeds = self.word_embeddings(sentences)
        gru_out, state = self.gru(embeds, state)
        tag_space = self.hidden2tag(gru_out.reshape(-1, 128))
        return tag_space.reshape(sentences.shape[0], sentences.shape[1], -1), state

# %%
model = Network()

# %%
model.forward(X[0:1])[0].shape
# Out:
# torch.Size([1, 30, 35])

# %%
def generate_sentence(mdl):
    sentence = ['я', ' ', 'в', 'а', 'с']
    #sentence = ['а', 'х', ' ', 'н', 'о', 'ж', 'к', 'и']
    state = None
    for i in range(MAX_LEN):
        X = torch.Tensor([[CHAR_TO_INDEX[sentence[i]]]]).type(torch.long)
        if i == 0:
            result, state = mdl.forward(X)
        else:
            result, state = mdl.forward_state(X, state)
        prediction = result[0, -1, :]
        index_of_prediction = prediction.argmax()
        if i >= len(sentence) - 1:
            if index_of_prediction == 0:
                break
        sentence.append(INDEX_TO_CHAR[index_of_prediction])
    print(''.join(sentence))

# %%
generate_sentence(model)
# Out:
# я василхзаияаиёииёбииии ииии виии и

# %%
def learning_loop(mdl, epochs=2000, optimizer=None):
    criterion = torch.nn.CrossEntropyLoss()
    for ep in range(epochs):
        start = time.time()
        train_loss = 0.
        train_passed = 0

        for i in range(int(len(X) / 100)):
            batch = X[i * 100:(i + 1) * 100]
            X_batch = batch[:, :-1]
            Y_batch = batch[:, 1:].flatten()

            optimizer.zero_grad()
            answers, _ = mdl.forward(X_batch)
            answers = answers.view(-1, len(INDEX_TO_CHAR))
            loss = criterion(answers, Y_batch)
            train_loss += loss.item()

            loss.backward()
            optimizer.step()
            train_passed += 1

        print("Epoch {}. Time: {:.3f}, Train loss: {:.3f}".format(ep, time.time() - start, train_loss / train_passed))
        generate_sentence(mdl)

# %%
learning_loop(model, epochs=100, optimizer=torch.optim.SGD(model.parameters(), lr=.5))
# Out:
# Epoch 0. Time: 0.754, Train loss: 0.284
# я вастсзсnoneххояааогткnoneкоуоnone й тnoneимпо
# Epoch 1. Time: 0.645, Train loss: 0.284
# я вастсзсnoneххояааогткnoneкоуоnone й тnoneимпо
# Epoch 2. Time: 0.642, Train loss: 0.284
# я вастсзсnoneххояааогткnoneкоуоnone й йnoneимпnone
# Epoch 3. Time: 0.632, Train loss: 0.284
# я вастсзсnoneххояааогткnoneкоуоnone й тnoneимпо
# Epoch 4. Time: 0.723, Train loss: 0.284
# я вастсзсnoneххояааогткnoneкоаоnone ййнnonenoneртё
# Epoch 5. Time: 0.676, Train loss: 0.284
# я вастсзсnoneххояааогткnoneкоуоnoneой тnoneиnonenoneь
# Epoch 6. Time: 0.734, Train loss: 0.283
# я вастсзсnoneххояааогткnoneкоуоnone й йnoneимпnone
# Epoch 7. Time: 0.683, Train loss: 0.283
# я вастсзсnoneххояааогткnoneкоуоnoneой тnoneиnonenoneь
# Epoch 8. Time: 0.728, Train loss: 0.283
# я вастсзсnoneххояааогткnoneкоуоnoneой тnoneиnonenoneь
# Epoch 9. Time: 0.726, Train loss: 0.283
# я вастсзсnoneххояааогткnoneкоуоnoneой тnoneиnonenoneь
# Epoch 10. Time: 0.835, Train loss: 0.283
# я вастсзсnoneххояааогткnoneкоаоnoneоййнnoneгnonenoneи
# Epoch 11. Time: 0.843, Train loss: 0.283
# я вастсзсnoneххояааогткnoneкоуоnoneой тnoneиnonenoneь
# Epoch 12. Time: 0.792, Train loss: 0.283
# я вастсзсnoneххояааогттnoneкоаааойnonenonenoneжnonenonenone
# Epoch 13. Time: 0.784, Train loss: 0.283
# я вастсзсnoneххояааогткnoneкоуоnoneой тnoneиnonenoneь
# Epoch 14. Time: 0.897, Train loss: 0.283
# я вастсзсnoneххояааогттnoneкоаааойnonenonenoneжnonenonenone
# Epoch 15. Time: 0.860, Train loss: 0.283
# я вастсзсnoneххояааогткnoneкоаоnoneоййнnoneгnonenoneи
# Epoch 16. Time: 1.047, Train loss: 0.283
# я вастсзсnoneххояааогттnoneкоаааойnonenonenoneжnonenonenone
# Epoch 17. Time: 0.893, Train loss: 0.282
# я вастсзсnoneххояааогткnoneкоаоnoneоййнnoneгnonenoneи
# Epoch 18. Time: 0.845, Train loss: 0.282
# я вастсзсnoneххояааагттnonenoneсnoneаиnoneяnonenonenonenonenonenonenone
# Epoch 19. Time: 0.989, Train loss: 0.282
# я вастсзсnoneххояааогттnoneкоаааойnonenonenoneжnonenonenone
# Epoch 20. Time: 1.008, Train loss: 0.282
# я вастсзсnoneххояааагттnonenoneсnoneаиnoneяnonenonenonenonenonenonenone
# Epoch 21. Time: 0.986, Train loss: 0.282
# я вастсзсnoneххояааогттnoneкоаааойnonenonenoneжnonenonenone
# Epoch 22. Time: 1.022, Train loss: 0.282
# я вастсзсnoneххояааагттnonenoneсnoneаиnoneяnonenonenonenonenonenonenone
# Epoch 23. Time: 0.966, Train loss: 0.282
# я вастсзсnoneххояааогттnoneкоаааойnonenonenoneжnonenonenone
# Epoch 24. Time: 0.974, Train loss: 0.282
# я вастсзсnoneххояааагттnonenoneсnoneаиnoneяnonenonenonenonenonenonenone
# Epoch 25. Time: 1.022, Train loss: 0.282
# я вастсзсnoneххояааагттnonenoneсnoneаиnoneяnonenonenonenonenonenonenone
# Epoch 26. Time: 0.931, Train loss: 0.282
# я вастсзсnoneххояааагттnonenoneсnoneаиnoneяnonenonenonenonenonenonenone
# Epoch 27. Time: 0.988, Train loss: 0.282
# я вастсзсnoneххояааагттnonenoneсnoneаиnoneяnonenonenonenonenonenonenone
# Epoch 28. Time: 0.985, Train loss: 0.282
# я вастсзсnoneххояааагттnonenoneсnoneаиnoneяnonenonenonenonenonenonenone
# Epoch 29. Time: 0.937, Train loss: 0.282
# я вастсзсnoneххояааагттnonenoneсnoneаиnoneяnonenonenonenonenonenonenone
# Epoch 30. Time: 1.140, Train loss: 0.282
# я вастсзсnoneххояааагттnonenoneсnoneаиnoneяnonenonenonenonenonenonenone
# Epoch 31. Time: 0.785, Train loss: 0.281
# я вастсзсnoneххояааагттnonenoneсnoneаиnoneяnonenonenonenonenonenonenone
# Epoch 32. Time: 0.825, Train loss: 0.282
# я вастсзсnoneххояааагттnonenoneсnoneаиnoneяnonenonenonenonenonenonenone
# Epoch 33. Time: 0.752, Train loss: 0.282
# я вастсзсnoneххояааагттnonenoneсnoneаиnoneяnonenonenonenonenonenonenone
# Epoch 34. Time: 0.892, Train loss: 0.282
# я вастсзсnoneххояааагттnonenoneсnoneаиnoneяnonenonenonenonenonenonenone
# Epoch 35. Time: 0.746, Train loss: 0.283
# я вастсзсnoneххояааагттnonenoneсnoneаиnoneяnonenonenonenonenonenonenone
# Epoch 36. Time: 0.941, Train loss: 0.284
# я вастсзсnoneххояааагттnonenoneсраиnoneеаnonenonenonenonenonenone
# Epoch 37. Time: 0.918, Train loss: 0.289
# я вастсзсnoneи ояачут тийьсохnonenoneкнnonenonenonenoneо
# Epoch 38. Time: 0.953, Train loss: 0.537
# я вастсзсnoneияоялттнnoneинааnonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 39. Time: 0.767, Train loss: 0.952
# я васнсзсnoneояоялртнnoneнннеnoneооогnoneгнннnonenone
# Epoch 40. Time: 0.906, Train loss: 0.931
# я ваствзсnoneиооеетммnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 41. Time: 1.140, Train loss: 0.793
# я ваствзсnoneиоох ддмnoneзляоnonenoneяnoneнnonenonenonenonenonenonenone
# Epoch 42. Time: 0.887, Train loss: 0.656
# я ваствзсnoneхооя  вк кнnoneумряnoneгnoneажnoneиnonenone
# Epoch 43. Time: 0.770, Train loss: 0.657
# я вастсзсnoneияоеатттдnonenonenoneьаnonenonenonenoneрnonenonenonenoneгnone
# Epoch 44. Time: 1.049, Train loss: 0.568
# я ваствзсnoneхооя овк всддрnoneхооооовnonenoneн
# Epoch 45. Time: 1.086, Train loss: 0.518
# я вастсзсnoneияоелттнньнаыыяоnonenonenonenoneнnonenonenonenone
# Epoch 46. Time: 0.861, Train loss: 0.483
# я ваствзсnoneиеое тднnonenoneваиnonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 47. Time: 0.961, Train loss: 0.449
# я вастсзсnoneыяоелт тлььиьунnoneоnonenoneоnonenone noneг
# Epoch 48. Time: 0.965, Train loss: 0.409
# я вастсзсnoneхяоелаенйьсnoneьnonenoneяnonenonenonenonenonenonenonenonenone
# Epoch 49. Time: 1.025, Train loss: 0.380
# я вастсзсnoneхяоеаотнтлнnoneииаиnonenonenonenonenonenonenonenonenone
# Epoch 50. Time: 0.916, Train loss: 0.351
# я вастсзсnoneхяоеаатнтnonenonenoneииnonenonenonenonenonenonenonenonenonenonenone
# Epoch 51. Time: 1.261, Train loss: 0.339
# я вастсзсnoneхяоеаотнйлнnoneиnoneииnoneоnonenonenonenoneиnonenone
# Epoch 52. Time: 1.660, Train loss: 0.324
# я вастсзсnoneияоеатннйnonenoneыыnonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 53. Time: 1.633, Train loss: 0.313
# я вастсзсnoneхяоеаоенйлнйнnonenoneиnoneоnonenonenonenoneгnonenone
# Epoch 54. Time: 1.751, Train loss: 0.307
# я вастсзсnoneхяоеаоенйл йнnonenonenoneтиnonenonenonenonenonenonenone
# Epoch 55. Time: 1.589, Train loss: 0.303
# я вастсзсnoneхяоеаоентлнйнуыыnoneоnonenonenonenoneгnonenone
# Epoch 56. Time: 1.700, Train loss: 0.300
# я вастсзсnoneхяоеаоентлнйнуыыnoneоnonenonenonenoneгnonenone
# Epoch 57. Time: 1.775, Train loss: 0.297
# я вастсзсnoneхяоеаоенйлнйнnonenoneиnoneоnonenonenonenoneгnonenone
# Epoch 58. Time: 1.594, Train loss: 0.295
# я вастсзсnoneхяоеаоентлнйнуыыnoneоnonenonenonenoneгnonenone
# Epoch 59. Time: 1.711, Train loss: 0.294
# я вастсзсnoneхяоеаоенйлнйнnonenoneиnoneоnonenonenonenoneгnonenone
# Epoch 60. Time: 1.730, Train loss: 0.293
# я вастсзсnoneхяоеаоентлнйнуыыnoneоnonenonenonenoneгnonenone
# Epoch 61. Time: 1.840, Train loss: 0.292
# я вастсзсnoneхяоеаоентл йнуытnonenone йкnonenonenonenone
# Epoch 62. Time: 1.588, Train loss: 0.292
# я вастсзсnoneхяоеаоентлнйнуыыnoneоnonenonenonenoneгnonenone
# Epoch 63. Time: 1.595, Train loss: 0.291
# я вастсзсnoneхяоеаоентл йнуытnonenone йкnonenonenonenone
# Epoch 64. Time: 1.552, Train loss: 0.290
# я вастсзсnoneхяоеаоентл йнуытnonenone йкnonenonenonenone
# Epoch 65. Time: 1.702, Train loss: 0.290
# я вастсзсnoneхяоеаоентл йнуутnonenone  nonenonenonenonenone
# Epoch 66. Time: 1.503, Train loss: 0.289
# я вастсзсnoneхяоеаоентл йнуутnonenone  nonenonenonenonenone
# Epoch 67. Time: 1.403, Train loss: 0.289
# я вастсзсnoneхяоеаоентл йнуутnonenone  nonenonenonenonenone
# Epoch 68. Time: 1.513, Train loss: 0.288
# я вастсзсnoneхяоеаоентл йнуутnonenoneд nonenonenoneир
# Epoch 69. Time: 1.360, Train loss: 0.288
# я вастсзсnoneхяоеаоентл йнуутnonenoneд nonenonenoneиnone
# Epoch 70. Time: 1.366, Train loss: 0.288
# я вастсзсnoneхяоеаоентл йнууттnoneд noneоnoneим
# Epoch 71. Time: 1.293, Train loss: 0.287
# я вастсзсnoneхяоеаоентл йнууттnoneд noneоnoneим
# Epoch 72. Time: 1.340, Train loss: 0.287
# я вастсзсnoneхяоеаоентл йнууттnoneд noneоnoneим
# Epoch 73. Time: 1.313, Train loss: 0.287
# я вастсзсnoneхяоеаоентл йнууттnoneд noneоnoneим
# Epoch 74. Time: 1.363, Train loss: 0.286
# я вастсзсnoneхяоеаоентл йнууттnoneд noneоnoneим
# Epoch 75. Time: 1.300, Train loss: 0.286
# я вастсзсnoneхяоеаоентл йнууттnoneд noneоnoneим
# Epoch 76. Time: 1.392, Train loss: 0.286
# я вастсзсnoneхяоеаоентл йнууттnoneд noneоnoneим
# Epoch 77. Time: 1.319, Train loss: 0.286
# я вастсзсnoneхяоеаоентл йнууттnoneй noneоnonenonenone
# Epoch 78. Time: 1.339, Train loss: 0.285
# я вастсзсnoneхяоеаоентл йнууттnoneй noneоnonenonenone
# Epoch 79. Time: 1.340, Train loss: 0.285
# я вастсзсnoneхяоеаоентл йнууттnoneй noneоnonenonenone
# Epoch 80. Time: 1.350, Train loss: 0.285
# я вастсзсnoneхяоеаоентл йнууттnoneй noneоnonenonenone
# Epoch 81. Time: 1.595, Train loss: 0.285
# я вастсзсnoneхяоеаоентл йнууттnoneй noneоnonenonenone
# Epoch 82. Time: 1.368, Train loss: 0.285
# я вастсзсnoneхяоеааентлnonenoneьnoneаnonenonenonenonenonenonenonenonenonenone
# Epoch 83. Time: 1.358, Train loss: 0.285
# я вастсзсnoneхяоеаоентл йнууттnoneй noneоnonenonenone
# Epoch 84. Time: 1.298, Train loss: 0.285
# я вастсзсnoneхяоеааенйлnonenoneьnoneуnonenonenonenonenonenonenonenonenonenone
# Epoch 85. Time: 1.364, Train loss: 0.284
# я вастсзсnoneхяоеаоенйл йнnoneаnoneтиnoneдnonenonenonenoneи
# Epoch 86. Time: 1.375, Train loss: 0.284
# я вастсзсnoneхяоеааенйлnonenoneьnoneуnonenonenonenonenonenonenonenonenonenone
# Epoch 87. Time: 1.749, Train loss: 0.284
# я вастсзсnoneхяоеаоенйл йнnoneаnoneтиnoneдnonenonenonenoneи
# Epoch 88. Time: 1.400, Train loss: 0.284
# я вастсзсnoneхяоеаоенйл йнnoneаnoneтиnoneдnonenonenonenoneи
# Epoch 89. Time: 1.448, Train loss: 0.284
# я вастсзсnoneхяоеааенйлnonenoneьnoneуnonenonenonenonenonenonenonenonenonenone
# Epoch 90. Time: 1.436, Train loss: 0.283
# я вастсзсnoneхяоеааенйлnonenoneьnoneуnonenonenonenonenonenonenonenonenonenone
# Epoch 91. Time: 1.499, Train loss: 0.283
# я вастсзсnoneхяоеааенйлnonenoneьnoneуnonenonenonenonenonenonenonenonenonenone
# Epoch 92. Time: 1.496, Train loss: 0.283
# я вастсзсnoneхяоеааенйлnonenoneьnoneуnonenonenonenonenonenonenonenonenonenone
# Epoch 93. Time: 1.285, Train loss: 0.283
# я вастсзсnoneхяоеааенйлnonenoneьnoneуnonenonenonenonenonenonenonenonenonenone
# Epoch 94. Time: 1.420, Train loss: 0.283
# я вастсзсnoneхяоеааенйлnonenoneьnoneуnonenonenonenonenonenonenonenonenonenone
# Epoch 95. Time: 1.386, Train loss: 0.283
# я вастсзсnoneхяоеааенйлnonenoneьnoneуnonenonenonenonenonenonenonenonenonenone
# Epoch 96. Time: 1.389, Train loss: 0.283
# я вастсзсnoneхяоеааенйлnonenoneьnoneуnonenonenonenonenonenonenonenonenonenone
# Epoch 97. Time: 1.265, Train loss: 0.282
# я вастсзсnoneхяоеааенйлnonenoneьnoneуnonenonenonenonenonenonenonenonenonenone
# Epoch 98. Time: 1.354, Train loss: 0.282
# я вастсзсnoneхяоеааенйлnonenoneьnoneуnonenonenonenonenonenonenonenonenonenone
# Epoch 99. Time: 1.404, Train loss: 0.282
# я вастсзсnoneххоеааатдттnonenoneуииnonenonenonenonenonenonenonenonenone

# %%
model = NetworkGRU()
learning_loop(model, epochs=100, optimizer=torch.optim.Adam(model.parameters(), lr=.5))
# Out:
# Epoch 0. Time: 1.264, Train loss: 21.416
# я васакррйздееnoneаеееnonenoneдддnonenoneеееnonenoneдддnone
# Epoch 1. Time: 1.408, Train loss: 14.819
# я васянаnoneя  о  о оо ооооооооооооооо
# Epoch 2. Time: 1.433, Train loss: 9.817
# я васора ьййс   ьньпп ь ооь пвв ьоо
# Epoch 3. Time: 1.575, Train loss: 6.739
# я вас соnoneтногnoneоггоnoneгоооnoneин бnonenoneнннnonenone
# Epoch 4. Time: 1.384, Train loss: 6.158
# я васгжо тоаеnoneецnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 5. Time: 1.390, Train loss: 7.595
# я васгхыnone оnonenonenoneо nonenonenone nonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 6. Time: 1.356, Train loss: 8.712
# я васвшыстыуnoneтрnoneюnonenoneнnonenonenonenoneаnonenonenonenoneкnonenonenonenoneн
# Epoch 7. Time: 1.370, Train loss: 9.655
# я васябnonenonenoneраnonenonenoneоnonenonenonenoneрnonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 8. Time: 1.362, Train loss: 9.455
# я васххекьоодояnonenoneоnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 9. Time: 1.397, Train loss: 8.234
# я васон noneяnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 10. Time: 1.419, Train loss: 7.041
# я вастоnoneййыйnonenonenoneйnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 11. Time: 1.462, Train loss: 6.867
# я васогоюкnoneв бвnoneовуоnoneгдвгnone  ввnoneвв none
# Epoch 12. Time: 1.421, Train loss: 6.360
# я васщрз nonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 13. Time: 1.375, Train loss: 6.024
# я васооажьттnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 14. Time: 1.498, Train loss: 6.042
# я васоооnoneьгггnonenoneооо none   ноооноьnonenoneо
# Epoch 15. Time: 1.349, Train loss: 4.795
# я васоооnoneьцццnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 16. Time: 1.410, Train loss: 4.563
# я васоооnoneоnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 17. Time: 1.414, Train loss: 5.808
# я вас войnoneвойnonenoneыйnonenonenoneй nonenonenone вnonenonenoneвыnonenonenone
# Epoch 18. Time: 1.770, Train loss: 5.241
# я васооойойййnone nonenonenonenoneоnonenonenonenoneгnonenonenonenoneоnonenonenonenone
# Epoch 19. Time: 1.659, Train loss: 6.823
# я вас в noneявовnonenone  оnonenoneввгnonenoneоооnonenonenonenonenonenonenone
# Epoch 20. Time: 1.758, Train loss: 7.078
# я васычо ойойэк    ачзччnoneооооnonenonenonenonenonenone
# Epoch 21. Time: 1.762, Train loss: 6.418
# я васько овонрнnoneяяаяnonenonenone nonenonenonenoneрnonenonenonenoneоnone
# Epoch 22. Time: 1.765, Train loss: 4.807
# я васьоо тnonenonenonenoneоnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 23. Time: 1.698, Train loss: 4.620
# я васоккnoneкnoneккnoneкnoneааёкnoneнннк ккааnoneка
# Epoch 24. Time: 1.668, Train loss: 6.566
# я вас го ооооотххххоооооййййй     о
# Epoch 25. Time: 1.435, Train loss: 6.322
# я ваства ьоо вбййв рnonenonenoneвnonenonenonenonenonenonenonenonenonenonenone
# Epoch 26. Time: 1.371, Train loss: 5.699
# я васьоо ооойойййnone nonenonenonenoneоnonenonenonenonenonenonenonenonenonenonenone
# Epoch 27. Time: 1.495, Train loss: 5.765
# я васьрр кnoneооррnoneггггnonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 28. Time: 1.559, Train loss: 6.583
# я вас кквякррав оивикжвава ививввив
# Epoch 29. Time: 1.641, Train loss: 5.759
# я васрозряомвоnoneмnoneыйnonenonenoneйnonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 30. Time: 1.828, Train loss: 4.758
# я вас кашяка ь о кякввр оцыыкрыййои
# Epoch 31. Time: 1.617, Train loss: 6.047
# я васьзо оnoneоппйnonenoneооnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 32. Time: 1.799, Train loss: 6.279
# я вас кк ккуокуоююук   кукккркоооуу
# Epoch 33. Time: 1.710, Train loss: 7.458
# я васвкоккооркоркройрnoneркnoneсnoneщиnoneлnoneикnone
# Epoch 34. Time: 1.777, Train loss: 6.688
# я васьт  ьnoneьnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 35. Time: 1.653, Train loss: 6.770
# я вас вожяяойнnonenoneйnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 36. Time: 1.299, Train loss: 5.632
# я васьврвкроаооойййййnonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 37. Time: 1.309, Train loss: 4.814
# я ваствоnoneтоыnonenonenonenoneйnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 38. Time: 1.458, Train loss: 5.785
# я васчвр яяяувnonenonenoneзрnonenonenoneяуnonenonenonenoneзnonenonenonenoneрnone
# Epoch 39. Time: 1.362, Train loss: 7.820
# я васвтоятояр  none  ттnoneттрвnone   цnoneттта
# Epoch 40. Time: 1.452, Train loss: 6.469
# я вастп  тооппnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 41. Time: 1.630, Train loss: 5.744
# я васкво noneоnonenonenonenoneрnonenonenonenoneыnonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 42. Time: 1.338, Train loss: 5.337
# я васьnone  ь nonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 43. Time: 1.322, Train loss: 5.910
# я вас жо оон очноочеоййен nonenonenoneооnonenonenoneн
# Epoch 44. Time: 1.321, Train loss: 6.731
# я вас зызnoneоойоnoneтэ nonenonenonenoneзnonenonenonenoneоnonenonenonenonenonenonenone
# Epoch 45. Time: 1.308, Train loss: 7.040
# я васмвн ьоыоввйnone нн noneооьоnoneюшnoneйnonenoneн
# Epoch 46. Time: 1.373, Train loss: 6.334
# я вас ор оой нйн оо оойройх ейnone ор
# Epoch 47. Time: 1.364, Train loss: 5.508
# я васт о ооорпррроnoneооойnonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 48. Time: 1.476, Train loss: 4.990
# я вас noneгжnonenonenoneоаnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 49. Time: 1.359, Train loss: 6.165
# я вас   р рууруnonenoneьnoneьnonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 50. Time: 1.357, Train loss: 6.106
# я васряорьоnonenonenonenoneйnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 51. Time: 1.437, Train loss: 5.516
# я вастпзйкоnoneьnonenone  nonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 52. Time: 1.480, Train loss: 6.460
# я васйп тйййкйййй     пппппйййййййй
# Epoch 53. Time: 1.475, Train loss: 6.051
# я васрва каарворриаюnonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 54. Time: 1.495, Train loss: 5.354
# я вастnoneрщьоаоnone й йnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 55. Time: 1.458, Train loss: 7.719
# я вас ннщьооыоцокшььnoneаынюnoneюоокnoneккка
# Epoch 56. Time: 1.489, Train loss: 6.752
# я вас й  кпнппоnoneьnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 57. Time: 1.314, Train loss: 5.309
# я вас в  яр ккnoneяк оnone  врnoneээnoneаnonenonenonenonenonenone
# Epoch 58. Time: 1.346, Train loss: 7.291
# я васткыnoneтыыnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 59. Time: 1.358, Train loss: 7.705
# я васюйоньо noneо йгnoneггн noneооооnoneннннnoneоо
# Epoch 60. Time: 1.376, Train loss: 9.079
# я вастnoneрnoneььnonenonenone  nonenonenonenoneтnonenonenonenoneьnonenonenonenone nonenonenonenone
# Epoch 61. Time: 1.387, Train loss: 7.689
# я васшооnoneьнйнnonenoneоnoneоnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 62. Time: 1.298, Train loss: 5.205
# я вас о  торцрьрцыыnoneыыnonenonenoneййnonenonenonenonenonenonenonenone
# Epoch 63. Time: 1.475, Train loss: 6.741
# я вас б  nonenoneыnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 64. Time: 1.380, Train loss: 5.667
# я вас п  кпопвоойооййnonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 65. Time: 1.373, Train loss: 5.759
# я вас б  коыооо й   nonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 66. Time: 1.493, Train loss: 5.977
# я васйу йо йунцйнйыоnoneыnoneййnoneйnone  nonenonenonenoneк
# Epoch 67. Time: 1.866, Train loss: 6.318
# я васшбыnoneь ыnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 68. Time: 1.950, Train loss: 6.301
# я васшбррььрооnonenoneойnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 69. Time: 2.167, Train loss: 7.316
# я вастмо оьо мтnone оооnoneотттnoneтьььnoneьnonenonenone
# Epoch 70. Time: 2.125, Train loss: 7.649
# я вас вотвроnoneьоьnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 71. Time: 1.776, Train loss: 6.554
# я вас рарьрррnonenoneаааnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 72. Time: 1.568, Train loss: 5.944
# я вас йш ярnoneёп  none яппnoneп ррnoneрпяяnoneяяnone
# Epoch 73. Time: 1.291, Train loss: 5.158
# я васщооркорnoneаоооnonenoneтттnonenoneьььnonenone nonenonenonenoneо
# Epoch 74. Time: 1.248, Train loss: 4.502
# я васшпзшьаоы   ййпппnonenoneоооnonenonenonenonenonenonenonenonenone
# Epoch 75. Time: 1.124, Train loss: 4.833
# я васшркяяаыы й йшрnoneрnone ы ы ршрврооы
# Epoch 76. Time: 1.117, Train loss: 6.732
# я вас ш  ьо оояйоаатnone   ьnoneооояnone
# Epoch 77. Time: 1.209, Train loss: 6.144
# я васр  ооооорввввояяяяnonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 78. Time: 1.227, Train loss: 5.182
# я васнр роnoneиранnoneраnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 79. Time: 1.346, Train loss: 5.351
# я вас зззяяааа     зззззааааан    и
# Epoch 80. Time: 1.233, Train loss: 4.471
# я вас н  ьноннnoneоnoneооnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 81. Time: 1.327, Train loss: 3.797
# я вастоотто  оо nonenoneчжnonenonenoneьтnonenonenonenoneьnonenonenonenonenone
# Epoch 82. Time: 1.120, Train loss: 3.773
# я васюо  о  оороорвоnonenoneооnonenonenonenonenonenonenonenonenonenonenone
# Epoch 83. Time: 1.114, Train loss: 6.977
# я васщоыяоорй   ы ооойоррр  ооыообб
# Epoch 84. Time: 1.173, Train loss: 7.962
# я васщр  еёоррй noneааnoneрnoneйnonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 85. Time: 1.185, Train loss: 6.408
# я васщnoneзжкоnoneо овnone вноnoneвоокnoneоззо  оо
# Epoch 86. Time: 1.269, Train loss: 4.727
# я васйгы ьnonenoneйnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 87. Time: 1.360, Train loss: 4.769
# я васьпз    ьпннн  ьььпн    ьпннн
# Epoch 88. Time: 1.259, Train loss: 5.085
# я васшоорооnoneноннnoneяnoneяяnonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 89. Time: 1.117, Train loss: 6.609
# я васщвзnoneооnoneоnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 90. Time: 1.124, Train loss: 7.030
# я васяnoneаротnoneро рnoneо роnone нотnoneнатоnoneыяр
# Epoch 91. Time: 1.360, Train loss: 5.541
# я васмрр ооооонннннооооо     noneввввnone
# Epoch 92. Time: 1.315, Train loss: 4.210
# я васьnone  нnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 93. Time: 1.173, Train loss: 5.367
# я васйр     рррррааааа     рррррааа
# Epoch 94. Time: 1.536, Train loss: 7.155
# я васщр роёаэа  зазnoneкака  р рррараа
# Epoch 95. Time: 1.643, Train loss: 6.446
# я васяггnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 96. Time: 1.502, Train loss: 4.885
# я васьва     nonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 97. Time: 1.289, Train loss: 4.378
# я васьвоnonenonenone nonenonenonenoneвnonenonenonenoneоnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 98. Time: 1.218, Train loss: 5.402
# я васякгртяnoneооо none   о ооововввы ыыы
# Epoch 99. Time: 1.124, Train loss: 7.246
# я васьчаnoneкяунnoneо noneьnone nonenone nonenonenonenonenonenonenonenonenonenonenonenone

# %%
model = NetworkLSTM()
learning_loop(model, epochs=100, optimizer=torch.optim.SGD(model.parameters(), lr=.5))
# Out:
# Epoch 0. Time: 1.202, Train loss: 3.074
# я васnone nonenone nonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 1. Time: 1.112, Train loss: 2.745
# я вас
# Epoch 2. Time: 1.104, Train loss: 2.655
# я вас     ооооо      ооооо      ооо
# Epoch 3. Time: 1.379, Train loss: 2.605
# я вас оо  о  оо оо  о   о ооо о
# Epoch 4. Time: 1.325, Train loss: 2.568
# я вас оо оо  о  оо оо  о  оо оо  о
# Epoch 5. Time: 1.244, Train loss: 2.534
# я вас оо оо  н  нооооо      ооооон
# Epoch 6. Time: 1.339, Train loss: 2.501
# я вас оо оо  н  нооооо     нооооо
# Epoch 7. Time: 1.163, Train loss: 2.469
# я вас оо оо  в  ввооооо     нвооооо
# Epoch 8. Time: 1.071, Train loss: 2.438
# я вас оо оол вл  ооооон     ооооов
# Epoch 9. Time: 1.110, Train loss: 2.408
# я вас со ооо сл  втооооо     ввсооо
# Epoch 10. Time: 1.125, Train loss: 2.380
# я вас сососолт    аоооосл     ооооо
# Epoch 11. Time: 1.091, Train loss: 2.353
# я вас постсолтое  а  нссспоеето
# Epoch 12. Time: 1.285, Train loss: 2.329
# я вас постполтаолоа     сспппотооол
# Epoch 13. Time: 1.116, Train loss: 2.306
# я вас постполтаолоа     сппппооооол
# Epoch 14. Time: 1.079, Train loss: 2.285
# я вас постполтаолоа     сппппооооор
# Epoch 15. Time: 1.110, Train loss: 2.266
# я вас постполтаолоаnone   nonenonenoneппо noneоорс
# Epoch 16. Time: 1.098, Train loss: 2.249
# я вас постполтоолоа    noneспппотоооро
# Epoch 17. Time: 1.121, Train loss: 2.234
# я вас постпортоолаа   nonenoneсппо тоорсо
# Epoch 18. Time: 1.151, Train loss: 2.220
# я вас постпортаолааnone nonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 19. Time: 1.193, Train loss: 2.206
# я вас постполтаолааnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 20. Time: 1.227, Train loss: 2.196
# я вас полтполааолиnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 21. Time: 1.088, Train loss: 2.193
# я вас постпортаорааnone аnonenonenonenoneлnonenonenonenonenonenonenonenone
# Epoch 22. Time: 1.198, Train loss: 2.171
# я вас постпортоораа  аnonenoneсплnonenonenoneоаnonenonenone
# Epoch 23. Time: 1.135, Train loss: 2.163
# я вас полтпорооорай nonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 24. Time: 1.291, Train loss: 2.160
# я вас полтпороаорайnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 25. Time: 1.623, Train loss: 2.148
# я вас полтпорооорай  nonenonenonenoneпоnonenonenoneорnonenonenone
# Epoch 26. Time: 1.366, Train loss: 2.141
# я вас полтпорооорай  nonenonenoneппрnonenoneооеnonenonenone
# Epoch 27. Time: 1.019, Train loss: 2.128
# я вас полтпорооорай  аnone ппл сооасев
# Epoch 28. Time: 1.200, Train loss: 2.120
# я вас полтпорооорай  nonenonenonenoneпрnonenonenoneееnonenonenone
# Epoch 29. Time: 1.049, Train loss: 2.124
# я вас полтпорооорай  nonenonenonenoneпрnonenonenoneееnonenonenone
# Epoch 30. Time: 1.263, Train loss: 2.108
# я вас полтпорооорай  nonenonenonenoneпрnonenonenoneееnonenonenone
# Epoch 31. Time: 1.603, Train loss: 2.100
# я вас полтпорооорайnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 32. Time: 2.000, Train loss: 2.093
# я вас полтпорооора   аnoneсппл тооавор
# Epoch 33. Time: 2.039, Train loss: 2.090
# я вас полтпораоораnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 34. Time: 1.834, Train loss: 2.089
# я вас полтпорооора   иnoneсппл тооаоор
# Epoch 35. Time: 1.580, Train loss: 2.076
# я вас полтпорооораnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 36. Time: 1.567, Train loss: 2.072
# я вас полтпорооорий  nonenonenonenoneпрnonenonenoneееnonenonenone
# Epoch 37. Time: 1.511, Train loss: 2.066
# я вас полтпорооорий  nonenonenonenoneпрnonenonenoneееnonenonenone
# Epoch 38. Time: 1.739, Train loss: 2.061
# я вас полтпорооорий  nonenonenonenoneпрnonenonenoneееnonenonenone
# Epoch 39. Time: 1.572, Train loss: 2.052
# я вас полтпорооорийnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 40. Time: 1.558, Train loss: 2.052
# я вас полтпорооорий  nonenonenoneппрnonenoneееееnonenone
# Epoch 41. Time: 1.486, Train loss: 2.040
# я вас полтпорооори   nonenoneсспрnoneтеоеее
# Epoch 42. Time: 1.572, Train loss: 2.035
# я вас полтпорооори   инссплаееоедnonenone
# Epoch 43. Time: 1.532, Train loss: 2.043
# я вас полтпорооори   nonenoneсспрnoneтеоеnoneеnone
# Epoch 44. Time: 1.698, Train loss: 2.029
# я вас полтпорооорийnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 45. Time: 1.490, Train loss: 2.027
# я вас полтпорооорий  инnoneпп аnoneооолnonenone
# Epoch 46. Time: 1.561, Train loss: 2.020
# я вас полтпорооори   инссплаееоедnonenone
# Epoch 47. Time: 1.711, Train loss: 2.014
# я вас полтпорооойийnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 48. Time: 1.680, Train loss: 2.009
# я вас полтпорооойийnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 49. Time: 1.594, Train loss: 2.013
# я вас полтпорооойий  nonenonenoneппрnonenoneееееnonenone
# Epoch 50. Time: 1.635, Train loss: 1.997
# я вас полтпорооойи    noneспппртооееей
# Epoch 51. Time: 1.399, Train loss: 2.000
# я вас полтпорооойий nonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 52. Time: 1.240, Train loss: 1.998
# я вас полтпорооойи   nonenoneсппрnoneтеееnonenonenone
# Epoch 53. Time: 1.222, Train loss: 1.989
# я вас полтпорооойи   nonenoneсппрnoneтеееnonenonenone
# Epoch 54. Time: 1.170, Train loss: 1.988
# я вас полтпорооойи   nonenoneсппрnoneтеееnonenonenone
# Epoch 55. Time: 1.137, Train loss: 1.980
# я вас полтпорооейи   nonenoneсппрnoneтеееnonenonenone
# Epoch 56. Time: 1.110, Train loss: 1.978
# я вас полтпорооейи  nonenonenoneспрnonenonenoneееnonenonenonenone
# Epoch 57. Time: 1.064, Train loss: 1.974
# я вас постпортоориа  nonenonenoneссрnonenonenoneеаnonenonenone
# Epoch 58. Time: 1.177, Train loss: 1.968
# я вас постпортоериа nonenonenonenoneсnonenonenonenonenonenonenonenonenonenone
# Epoch 59. Time: 1.328, Train loss: 1.967
# я вас постпортоериа nonenonenonenoneсnonenonenonenonenonenonenonenonenonenone
# Epoch 60. Time: 1.571, Train loss: 1.966
# я вас постпортоериа  nonenonenoneссрnonenonenoneеаnonenonenone
# Epoch 61. Time: 1.505, Train loss: 1.955
# я вас постпортоериа  и noneсс пртевоеа
# Epoch 62. Time: 1.408, Train loss: 1.951
# я вас постпортоериа  и noneсс пnoneтевоеnone
# Epoch 63. Time: 1.496, Train loss: 1.957
# я вас постпортоериа  nonenonenoneссрnonenonenoneеаnonenonenone
# Epoch 64. Time: 1.198, Train loss: 1.948
# я вас постпортоериа nonenonenonenoneсnonenonenonenonenonenonenonenonenonenone
# Epoch 65. Time: 1.166, Train loss: 1.943
# я вас постпортоереа  noneнnoneссреnonenoneяадnonenone
# Epoch 66. Time: 1.078, Train loss: 1.939
# я вас постпортоереа  noneнnoneссреnonenoneяадnonenone
# Epoch 67. Time: 1.298, Train loss: 1.935
# я вас постпортоереа nonenoneнnoneсnonenonenonenonenonenonenonenonenonenone
# Epoch 68. Time: 1.187, Train loss: 1.932
# я вас постпортоереа  noneнnoneссреnonenoneяанnonenone
# Epoch 69. Time: 1.085, Train loss: 1.930
# я вас постпортоереа  noneнnoneссреnonenoneяанnonenone
# Epoch 70. Time: 1.784, Train loss: 1.927
# я вас постполтоерио  none  ссрпптеаеее
# Epoch 71. Time: 1.703, Train loss: 1.926
# я вас постполтоерио  none noneссрпnoneееаеnonenone
# Epoch 72. Time: 1.582, Train loss: 1.914
# я вас постполтоерио  и  сс пптевоое
# Epoch 73. Time: 1.161, Train loss: 1.916
# я вас постполтоерио nonenonenonenoneсnonenonenonenonenonenonenonenonenonenone
# Epoch 74. Time: 1.036, Train loss: 1.916
# я вас постполтоерио  и  сс пптевоое
# Epoch 75. Time: 1.244, Train loss: 1.911
# я вас постполтоерео nonenoneнnoneсnonenonenonenonenonenonenonenonenonenone
# Epoch 76. Time: 1.492, Train loss: 1.901
# я вас постполтоерео  noneнnoneссееnonenoneяnonenonenonenone
# Epoch 77. Time: 1.423, Train loss: 1.905
# я вас постполтоерео nonenoneнnoneсnonenoneеnonenonenonenonenonenonenone
# Epoch 78. Time: 1.372, Train loss: 1.899
# я вас постполтоерео nonenoneнnoneсnonenoneеnonenonenonenonenonenonenone
# Epoch 79. Time: 1.183, Train loss: 1.899
# я вас постполтоерео  noneнnoneссееnonenoneяnonenonenonenone
# Epoch 80. Time: 1.129, Train loss: 1.892
# я вас постполтоерео  ьн ссреоееадnonenone
# Epoch 81. Time: 1.061, Train loss: 1.901
# я вас постполтоерео nonenoneнnoneсnonenoneеnonenonenonenonenonenonenone
# Epoch 82. Time: 1.090, Train loss: 1.885
# я вас постполтоерео  noneнnoneссnoneеnonenoneяnonenonenonenone
# Epoch 83. Time: 1.112, Train loss: 1.881
# я вас постполтоерео  noneнnoneссееnonenoneяnonenonenonenone
# Epoch 84. Time: 1.167, Train loss: 1.880
# я вас постполтоерео  noneнnoneссееnonenoneяnonenonenonenone
# Epoch 85. Time: 1.304, Train loss: 1.872
# я вас п стпоптрррееааанн nonenoneьыиnonenonenonenonenone
# Epoch 86. Time: 1.433, Train loss: 1.873
# я вас постполтоерео nonenonenonenoneсnonenonenonenonenonenonenonenonenonenone
# Epoch 87. Time: 1.374, Train loss: 1.868
# я вас п стпоптрррееааанн nonenoneьыиnonenonenonenonenone
# Epoch 88. Time: 1.351, Train loss: 1.869
# я вас п стпоптрррееааанн nonenoneьыиnonenonenonenonenone
# Epoch 89. Time: 1.457, Train loss: 1.863
# я вас постполтоерео  noneнnoneссnoneеnonenoneяnonenonenonenone
# Epoch 90. Time: 1.423, Train loss: 1.860
# я вас постполтоереовnonenoneнnonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 91. Time: 1.429, Train loss: 1.857
# я вас постполтоерео  noneнnoneссnoneеnonenoneяnonenonenonenone
# Epoch 92. Time: 1.262, Train loss: 1.852
# я вас п стпоптрррееааанн nonenoneьыиnonenonenonenonenone
# Epoch 93. Time: 1.186, Train loss: 1.848
# я вас п стпоптрррееааанн nonenoneьывnonenonenonenonenone
# Epoch 94. Time: 1.153, Train loss: 1.850
# я вас п стпоптрррееааанн  льыивабnonenone
# Epoch 95. Time: 1.179, Train loss: 1.843
# я вас п стпоптрррееааанн лльыиеанnonenone
# Epoch 96. Time: 1.226, Train loss: 1.841
# я вас п стпоптррреоаааннnonenonenoneьыnonenonenonenonenonenone
# Epoch 97. Time: 1.136, Train loss: 1.838
# я вас п стпоптрррееааанн  noneьыивnonenonenonenone
# Epoch 98. Time: 1.080, Train loss: 1.840
# я вас постполтоереовnonenoneнnonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 99. Time: 1.125, Train loss: 1.831
# я вас п стпостррртааааан nonenonenoneьвnonenonenonenonenone

# %%
model = NetworkUber()
learning_loop(model, epochs=100, optimizer=torch.optim.SGD(model.parameters(), lr=.5))
# Out:
# Epoch 0. Time: 1.515, Train loss: 3.003
# я васnone    nonenonenone   nonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 1. Time: 1.502, Train loss: 2.714
# я вас  е   еееееее  nonenonenone   nonenonenonenone  nonenonenone
# Epoch 2. Time: 1.540, Train loss: 2.632
# я вас ооооее  nonenonenone о nonenonenonenoneо nonenonenonenonenonenonenonenonenone
# Epoch 3. Time: 1.455, Train loss: 2.600
# я вас оооооое nonenonenonenone nonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 4. Time: 1.597, Train loss: 2.576
# я вас оооооое nonenonenonenone nonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 5. Time: 1.544, Train loss: 2.560
# я вас оооооое nonenonenonenoneоnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 6. Time: 1.978, Train loss: 2.545
# я вас оооооое nonenonenonenoneеnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 7. Time: 1.813, Train loss: 2.533
# я вас оооооое nonenonenonenoneеnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 8. Time: 2.067, Train loss: 2.522
# я вас оооооое nonenonenonenoneоnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 9. Time: 1.812, Train loss: 2.513
# я вас ооооооеnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 10. Time: 1.873, Train loss: 2.503
# я вас ооооооеnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 11. Time: 2.006, Train loss: 2.493
# я вас ооооооеnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 12. Time: 1.892, Train loss: 2.482
# я вас ооооооеnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 13. Time: 1.736, Train loss: 2.470
# я вас ооооооеnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 14. Time: 1.903, Train loss: 2.457
# я вас оооооорnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 15. Time: 2.279, Train loss: 2.441
# я вас оооооорnonenonenonenoneнnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 16. Time: 1.781, Train loss: 2.422
# я вас ооооорлnonenonenoneнаnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 17. Time: 1.782, Train loss: 2.399
# я вас ооооорлnonenonenoneнаnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 18. Time: 1.842, Train loss: 2.371
# я вас оореорлонnoneоаnoneаnonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 19. Time: 1.923, Train loss: 2.340
# я вас оореорлонnoneоаnoneаnonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 20. Time: 1.787, Train loss: 2.307
# я вас порерорананоnoneаnonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 21. Time: 1.722, Train loss: 2.283
# я вас пор нолеса еnonenonenoneннnonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 22. Time: 1.828, Train loss: 2.255
# я вас пор полесоленnonenoneиnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 23. Time: 2.146, Train loss: 2.237
# я вас полтполеаа ь nonenoneн срnonenoneпрарnonenoneал
# Epoch 24. Time: 2.110, Train loss: 2.202
# я вас полтполеаа nonenonenonenoneнnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 25. Time: 1.891, Train loss: 2.216
# я вас полтполеаайnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 26. Time: 1.931, Train loss: 2.179
# я вас полтполеааnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 27. Time: 1.784, Train loss: 2.183
# я вас полтполеаайnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 28. Time: 1.831, Train loss: 2.170
# я вас полттолеааnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 29. Time: 1.821, Train loss: 2.168
# я вас полттолеао nonenonenonenoneсnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 30. Time: 1.918, Train loss: 2.163
# я вас полттолеаоnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 31. Time: 1.734, Train loss: 2.141
# я вас полттолааоnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 32. Time: 1.749, Train loss: 2.141
# я вас полттолааоnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 33. Time: 1.605, Train loss: 2.135
# я вас полттолеооnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 34. Time: 1.847, Train loss: 2.132
# я вас полттолеоо     ссрррртаааааnonenone
# Epoch 35. Time: 1.725, Train loss: 2.127
# я вас полттолеоо nonenonenonenoneсnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 36. Time: 1.881, Train loss: 2.117
# я вас полттолаооnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 37. Time: 1.784, Train loss: 2.107
# я вас полттораооnoneиnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 38. Time: 1.828, Train loss: 2.104
# я вас полтпораоойиnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 39. Time: 1.848, Train loss: 2.097
# я вас полттореооnoneиnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 40. Time: 1.635, Train loss: 2.099
# я вас полттореоо и nonenoneс пnonenonenonenoneоnonenonenonenonenonenone
# Epoch 41. Time: 1.839, Train loss: 2.090
# я вас полтпораоойиnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 42. Time: 2.015, Train loss: 2.073
# я вас полтпораоойиnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 43. Time: 2.221, Train loss: 2.074
# я вас полтпореоойиnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 44. Time: 1.833, Train loss: 2.073
# я вас полтпореоо ин noneс апnoneтпррnonenoneоаа
# Epoch 45. Time: 1.754, Train loss: 2.066
# я вас полтпореоойинnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 46. Time: 1.707, Train loss: 2.062
# я вас полтпореоойинnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 47. Time: 1.988, Train loss: 2.045
# я вас полтпореоойинnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 48. Time: 1.794, Train loss: 2.053
# я вас полтпореоойинnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 49. Time: 1.700, Train loss: 2.040
# я вас полтпореоойинnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 50. Time: 1.805, Train loss: 2.038
# я вас полтпореоойинnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 51. Time: 1.879, Train loss: 2.034
# я вас постпортоолиоnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 52. Time: 2.004, Train loss: 2.029
# я вас постпортоолиоnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 53. Time: 1.845, Train loss: 2.015
# я вас постпортоолиоnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 54. Time: 2.077, Train loss: 2.016
# я вас постпортоолиоnonenonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 55. Time: 2.228, Train loss: 2.014
# я вас постпортоолио  ьnonenoneсв nonenonenoneеnonenonenonenone
# Epoch 56. Time: 1.988, Train loss: 2.006
# я вас постпортоолиоnonenoneьnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 57. Time: 1.871, Train loss: 2.007
# я вас постпортоолиоnonenoneьnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 58. Time: 2.382, Train loss: 1.993
# я вас постпортоолио  ьnonenoneсв nonenonenoneеnonenonenonenone
# Epoch 59. Time: 3.136, Train loss: 1.990
# я вас постпортоолио  ьnonenoneсв nonenonenoneеnonenonenonenone
# Epoch 60. Time: 2.262, Train loss: 1.978
# я вас постпортоолио  ьnonenoneсв nonenonenoneеnonenonenonenone
# Epoch 61. Time: 2.045, Train loss: 1.988
# я вас постпортоолиойnoneьnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 62. Time: 2.085, Train loss: 1.983
# я вас постпортролиоаnonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 63. Time: 1.900, Train loss: 1.976
# я вас постпортролиоаnonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 64. Time: 1.990, Train loss: 1.966
# я вас постпортролиоаnonenonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 65. Time: 2.103, Train loss: 1.962
# я вас постпортролиоайnonenonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 66. Time: 1.994, Train loss: 1.957
# я вас постпортролиоаnoneьnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 67. Time: 2.000, Train loss: 1.958
# я вас постпортролиеаnoneьnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 68. Time: 3.482, Train loss: 1.951
# я вас постпортролиоайьnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 69. Time: 3.485, Train loss: 1.943
# я вас постпортролиоайьnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 70. Time: 3.738, Train loss: 1.940
# я вас постпортролиеайьnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 71. Time: 2.173, Train loss: 1.949
# я вас постпортролиеайьnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 72. Time: 1.904, Train loss: 1.931
# я вас постпортоолие  ьnonenoneсв nonenonenoneеnonenonenonenone
# Epoch 73. Time: 1.862, Train loss: 1.925
# я вас постпортоолие  ьnonenoneсв nonenonenoneеnonenonenonenone
# Epoch 74. Time: 2.196, Train loss: 1.921
# я вас постпортоолие  ьnonenoneсв nonenonenoneеnonenonenonenone
# Epoch 75. Time: 2.414, Train loss: 1.922
# я вастпостоолтойньойnoneоnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 76. Time: 2.096, Train loss: 1.915
# я вас постпортоолие  ьnonenoneсв nonenonenoneеnonenonenonenone
# Epoch 77. Time: 1.979, Train loss: 1.908
# я вас постпортоолие  ьnonenoneсв nonenonenoneеnonenonenonenone
# Epoch 78. Time: 1.929, Train loss: 1.918
# я вас постпортоолие  ьnonenoneсв nonenonenoneеnonenonenonenone
# Epoch 79. Time: 1.979, Train loss: 1.903
# я вас постпортоолие  ьnonenoneсн nonenonenoneиnonenonenonenone
# Epoch 80. Time: 2.437, Train loss: 1.906
# я вас постпортоовие  noneлтснnoneеаяоnonenonenonenone
# Epoch 81. Time: 2.470, Train loss: 1.895
# я вас постпортоовие  noneлтснnoneеаяоnonenonenonenone
# Epoch 82. Time: 2.889, Train loss: 1.891
# я вас постпортоевие  noneлтсвnoneааяоnonenonenonenone
# Epoch 83. Time: 3.306, Train loss: 1.885
# я вас постпортоевие  noneлnoneсвnoneеnonenoneиnonenonenonenone
# Epoch 84. Time: 2.614, Train loss: 1.885
# я вас постпортоевие  noneлтсвnoneааяоnonenonenonenone
# Epoch 85. Time: 2.759, Train loss: 1.873
# я вас состптвтрееееинт nonenoneьnonenonenonenonenonenonenonenonenone
# Epoch 86. Time: 2.849, Train loss: 1.882
# я вас состптвтрееееенттnonenoneьnoneеnonenonenonenonenonenonenone
# Epoch 87. Time: 2.743, Train loss: 1.870
# я вас состптвтрееееентnonenonenoneьnonenonenonenonenonenonenonenonenone
# Epoch 88. Time: 2.678, Train loss: 1.869
# я вас состптвтрееееенттnonenoneьnoneеnonenonenonenonenonenonenone
# Epoch 89. Time: 3.878, Train loss: 1.865
# я вас состптвтрееееинт nonenoneьnoneсnonenonenonenonenonenonenone
# Epoch 90. Time: 16.789, Train loss: 1.859
# я вастсострявтииние  ьйnoneсв nonenoneеоnonenonenonenone
# Epoch 91. Time: 5.850, Train loss: 1.861
# я вастсострявтианиел ьnonenoneьс nonenonenoneяnonenonenonenone
# Epoch 92. Time: 5.087, Train loss: 1.854
# я вастсострявтииние  ьйnoneсв nonenoneееnonenonenonenone
# Epoch 93. Time: 4.024, Train loss: 1.846
# я вастсострявтииние  ьйnoneсв nonenoneееnonenonenonenone
# Epoch 94. Time: 3.839, Train loss: 1.840
# я вастсострявтииние  ьй св nonenoneтооnonenoneа
# Epoch 95. Time: 4.041, Train loss: 1.841
# я вастсострявтиание  ьnonenoneсв nonenoneееnonenonenonenone
# Epoch 96. Time: 3.996, Train loss: 1.846
# я вас состптвтаееееnoneт nonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 97. Time: 3.977, Train loss: 1.843
# я вас сос птвтпооеее т тnoneпрмеnoneееенnone
# Epoch 98. Time: 3.671, Train loss: 1.828
# я вас состптвтаееееnoneттnonenonenonenonenonenonenonenonenonenonenonenonenone
# Epoch 99. Time: 3.778, Train loss: 1.827
# я вастсос рявтвадиеельлтnoneьноеnonenoneоnonenonenone
